# %% [markdown]
# ## Plan du travail
#
# Le Projet consiste à étudier la vente des médicaments et implémenter des modèles de prédictions pouvant permettre de préduire le comportement à l'avenir en fonction des comportements passés et actuels en utilisant des notions de séries temporelles.
#
# Pour ce fait, nous allons parcourir différentes notions vues au cours allant de l'analyse basique des séries temporelles, à leurs modélisations avec différentes approches à savoir la méthode statisque et la méthode d'apprentissage profond. Mais aussi déffinir des mésures de précision permettant des voir quel modèle implémenté semble meilleur que l'autre en fonction des données que contient notre dataset.
#
# Avant d'aller plus loin, il est important d'appréhender certaines notions liées à ce travail facilant sa compréhension.
#
# **C'est quoi une série temporelle ou chronologique ?**
#
# >`Une série chronologique` est définie comme une série de points de données enregistrés à différents intervalles de temps. L'ordre chronologique peut être quotidien, mensuel ou même annuel.
#
# **Qu'entends-t-on par prévion des séries temporelles ?**
#
# >`La prévision des séries temporelles` est le processus qui consiste à utiliser un modèle statistique pour prédire les valeurs futures d'une série temporelle sur la base des résultats passés. De manière plus simple, c'est l'étape où nous voulons prédire les valeurs futures que la série va prendre.
#
# **Combien de catégories de prévisions existe-t-il ?**
#
# >La prévision d'une série chronologique peut être divisée en deux grandes catégories.
#
# * Si nous n'utilisons que les valeurs précédentes de la série temporelle pour prédire ses valeurs futures, il s'agit d'une `prévision de série temporelle univariée`.
#
# * Si nous utilisons des prédicteurs autres que la série (comme les variables exogènes) pour prévoir, on parle de `prévision de séries temporelles multi-variées`.

# %% [markdown]
# **Table des matières**
#
# 1. [Analyse Fondamentale](#BasicAnalytics)
#     * [Préparation des données](#DataPreparation)
#     * [Visualisation des données](#DataVisualization)
#     * [Séparation des donnnées](#DataSplitting)
#     * [Décomposition des séries temporelles](#TimeSeriesDecomposition)
#
# 2. [Mesures de Précision pour les prévisions des séries temporelles](#AccuracyMetrics)
#
# 3. [Modélisation des séries chronologiques avec la méthode statistique](#TimeSeriesModelingwithStatisticalMethod)
#     * [Naive Forecast](#NaiveForecast)
#     * [Moyenne mobile exponentielle](#ExponentialMovingAverage)
#         * [Moyenne mobile exponentielle simple (SEMA)](#SimpleExponentialMovingAverage(SEMA))
#         * [Méthode de la moyenne mobile exponentielle Holt-Winters](#Holt-WintersMethod)
#     * [ARIMA Forecast](#ARIMAForecast)
#     * [SARIMA Forecast](#SARIMAForecast)
#
# 4. [Modélisation des séries temporelles avec le Deep Learning](#TimeSeriesModelingwithDeepLearning)
#     * [Prétraitement des données](#Preprocessing)
#     * [MLP](#MLP)
#         * [Modélisation](#ModelingMLP)
#         * [Formation](#TrainingMLP)
#         * [Evaluation](#EvaluationMLP)
#     * [LSTM](#LSTM)
#         * [Modélisation](#ModelingLSTM)
#         * [Formation](#TrainingLSTM)
#         * [Evaluation](#EvaluationLSTM)
#
# 5. [Conclusion](#Conclusion)

# %%
from google.colab import drive
drive.mount('/content/Dataset')

# %%
# Import packages
import math
import torch
import itertools
import numpy as np
import pandas as pd
import torch.nn as nn
import seaborn as sns
from numpy import log
import statsmodels.api as sm
from matplotlib import pylab
import torch.nn.functional as F
import matplotlib.pyplot as plt
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima.model import ARIMA
from tensorflow.keras.models import Sequential
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf , plot_pacf
from torch.utils.data import Dataset, DataLoader, TensorDataset
from statsmodels.tsa.holtwinters import Holt, ExponentialSmoothing, SimpleExpSmoothing

# %matplotlib inline 
pylab.rcParams['figure.figsize'] = (10.0, 8.0)
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## <a name="BasicAnalytics">1. Analyse Fondamentale</a>

# %% [markdown]
# ### <a name="DataPreparation">a - Préparation et visualisation des données
# Importons le dataset et faisons de la colonne `Date` l'index puis définissons la fréquence

# %% [markdown]
# #### **Préparation des données**

# %%
# Importons le CSV
medoc_df = pd.read_csv("/Users/harouna/Documents/Horizon/Time Series/Time_Series_Projet/data/drug_sales.txt")
df = medoc_df
df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date')
df.index.freq ='MS'
df.head()
# Out:
#                value
# date
# 1991-07-01  3.526591
# 1991-08-01  3.180891
# 1991-09-01  3.252221
# 1991-10-01  3.611003
# 1991-11-01  3.565869

# %%
df.shape
# Out:
# (204, 1)

# %% [markdown]
# #### **Visualisation des données**

# %%
# Visualisons nos séries
df.plot(figsize=(12,5))
plt.title("Séries temporelles de Ventes de médicaments")
plt.xlabel("Date")
plt.ylabel("Ventes au détail mensuelles")
# Out:
# Text(0, 0.5, 'Ventes au détail mensuelles')

# %% [markdown]
# ### <a name="DataSplitting">b - Séparation des données
# Diviser les données en données de formation et de test en utilisant `train_test_split`.
#
# Comme notre dataset comportes des données sur 204 mois, utilisons les 180 prémiers mois comme données de formation et les 24 derniers mois comme donnée de test hors du temps.

# %%
# Créer des données de formations et de tests
split_ratio = 0.885
train, test = train_test_split(df, train_size=split_ratio , shuffle = False)
train_time,test_time = train.index, test.index

#print(train.shape)
#print(test.shape)

# %% [markdown]
# ### <a name="TimeSeriesDecomposition">c - Décomposition des séries temporelles
# La décomposition nous donne plus de détails sur le modèle de données des séries chronologiques en décomposant les données en `tendance`, `saisonnalité` et `résidu`.

# %% [markdown]
# #### **Decomposition additive**

# %%
# Decomposition additive
add_decomposition = seasonal_decompose(train, model='additive')
add_decomposition.plot()

plt.show()

# %% [markdown]
# #### **Decomposition multiplicative**

# %%
# Decomposition multiplicative
mul_decomposition = seasonal_decompose(train, model='multiplicative')
mul_decomposition.plot()

plt.show()

# %% [markdown]
# ## <a name="AccuracyMetrics">2. Mesures de Précision pour les prévisions des séries temporelles

# %%
# Calculer des metriques des modèles chosis
def forcast_accuracy(forecast, actual):
    #mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    #corr = np.corrcoef(forecast, actual)[0,1]   # corr
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    return rmse#({'mape':mape,'rmse':rmse,'corr':corr})

# %% [markdown]
# ## <a name="TimeSeriesModelingwithStatisticalMethod">3. Modélisation des séries chronologiques avec la méthode statistique

# %% [markdown]
# #### **Fonction de traçage des données de prévisions**

# %%
# Fonction pour tracer les données de la prévision
def forecast_plot(forecast_data,forecast_label, test_label='Test Data',test_time = test_time,test_data= test):
    plt.figure(figsize=(12,6))
    plt.plot(test_time,forecast_data,'y',label = forecast_label,)
    plt.plot(test_time,test_data,label = test_label)
    plt.legend()
    plt.title("Prédiction")
    plt.xlabel("Mois")
    plt.ylabel("Ventes au détail")

# %% [markdown]
# ### <a name="NaiveForecast">a - Naive Forecast
# Tout d'abord, utilisons la méthode de prévision naïve comme modèle de référence.

# %%
# Tracer les données de la prévision
# Méthode de prévision naïve 
naive_forecast = test.shift(1)
forecast_plot(forecast_data = naive_forecast,forecast_label = 'Naive Forecast')

# %%
# Sauvegarder le résultat dans un Dataframe nommé P
Naïve_acc = forcast_accuracy(naive_forecast, test).value
Precision = pd.DataFrame({'NAÏVE ACC' :Naïve_acc},index=["RMSE"])
Precision
# Out:
#       NAÏVE ACC
# RMSE   3.969457

# %% [markdown]
# ### <a name="ExponentialMovingAverage">b - Moyenne mobile exponentielle

# %% [markdown]
# #### <a name="SimpleExponentialMovingAverage(SEMA)">1 - Moyenne mobile exponentielle simple (SEMA)
# Commençons par la moyenne mobile exponentielle simple (SEMA) pour déterminer si cette méthode est la bonne méthode à utiliser comme modèle de prévision.

# %%
# SEMA
sema = SimpleExpSmoothing(train).fit()
sema_forecast = sema.forecast(len(test))
#sema_forecast.head()

# Visualisation des données prévisionnelles
forecast_plot(forecast_data = sema_forecast,forecast_label = 'SEMA Forecast' )

# %%
# Ajout du resultat au dataframe Precision
sema_acc = forcast_accuracy(sema_forecast, test.value)
Precision['SEMA ACC'] =  sema_acc
Precision
# Out:
#       NAÏVE ACC  SEMA ACC
# RMSE   3.969457  6.142934

# %% [markdown]
# #### <a name="Holt-WintersMethod">2 - Méthode de la moyenne mobile exponentielle Holt-Winters

# %%
# Definissons la méthode de la moyenne mobile exponentielle Holt-Winters
method = ['ADD','MUL']
for trend in method:
    for seasonal in method:
        exponential = ExponentialSmoothing(train, seasonal_periods=12, trend = trend, seasonal= seasonal).fit()
        exponential_forecast = exponential.forecast(len(test))
        Precision[trend+'_'+seasonal+'_'+'ACC']= forcast_accuracy(exponential_forecast, test.value)

Precision
# Out:
#       NAÏVE ACC  SEMA ACC  ADD_ADD_ACC  ADD_MUL_ACC  MUL_ADD_ACC  MUL_MUL_ACC
# RMSE   3.969457  6.142934     3.105467     2.971185     2.648327       2.3696

# %% [markdown]
# D'après les précisons ci)dessus, la méthode de Holt-Winters à tendance multiplicative et à saisonnalité multiplicative semble meilleur pour la prévision, donc utilisons là pour notre prédiction.

# %%
# Utilisons la méthode de Holt-Winters à tendance multiplicative et à saisonnalité multiplicative pour la prévision.
exponential = ExponentialSmoothing(train, seasonal_periods=12, trend='MUL', seasonal='MUL').fit()
exponential_forecast = exponential.forecast(len(test))

# %%
# Visualisation des données prévisionnelles exponentielle
forecast_plot(forecast_data = exponential_forecast,forecast_label = 'Holt-Winters Method Forecast')

# %% [markdown]
# ### <a name="ARIMAForecast">c - ARIMA Forecast

# %% [markdown]
# >ARIMA est l'abréviation de Autoregressive Integrated Moving Average Model. Il appartient à une classe de modèles qui explique une série temporelle donnée sur la base de ses propres valeurs passées, c'est-à-dire ses propres retards et les erreurs de prévision retardées. L'équation peut être utilisée pour prévoir les valeurs futures. Toute série temporelle "non saisonnière" qui présente des caractéristiques et qui n'est pas un bruit blanc aléatoire peut être modélisée par des modèles ARIMA.
# Ainsi, ARIMA, abréviation de AutoRegressive Integrated Moving Average, est un algorithme de prévision basé sur l'idée que les informations contenues dans les valeurs passées de la série chronologique peuvent être utilisées seules pour prédire les valeurs futures.
# Les modèles ARIMA sont spécifiés par trois paramètres d'ordre : **(p, d, q)**,
# où :
#
# >1. `p` est l'ordre du terme AR
# >2. `q` est l'ordre du terme MA
# >3. `d` est le nombre de différenciations nécessaires pour rendre la série temporelle stationnaire.
#
# >Afin de pouvoir utiliser le modèle ARIMA, trois grandes questions se posent :
# >1. **Comment trouver l'ordre de différentiation (d) dans un modèle ARIMA ?**
# >2. **Comment trouver l'ordre du terme AR (p) ?**
# >3. **Comment trouver l'ordre du terme MA (q)**

# %% [markdown]
# #### **1 - Comment trouver l'ordre de différentiation (d) dans un modèle ARIMA ?**
# Comme indiqué précédemment, le but de la différenciation est de rendre la série temporelle stationnaire. Mais nous devons faire attention à ne pas trop différencier les séries.
#
# Vérifions si la série est stationnaire en utilisant le test de Dickey Fuller augmenté (test ADF). La raison en est que nous n'avons besoin de différencier que si la série est non stationnaire. Dans le cas contraire, aucune différenciation n'est nécessaire, c'est-à-dire que d=0. Ainsi, si la valeur p du test est inférieure au seuil de signification (0,05), on en déduisons que la série chronologique est stationnaire.

# %%
resultat = adfuller(medoc_df.value.dropna())
print('ADF Statistic: %f' % resultat[0])
print('p-value: %f' % resultat[1])
# Out:
# ADF Statistic: 3.145186
# p-value: 1.000000

# %% [markdown]
# Puisque la valeur p(1.00) est supérieure au niveau de signification(0.05), différencions les séries et voyons à quoi ressemble le graphique d'autocorrélation

# %%
plt.rcParams.update({'figure.figsize':(9,2), 'figure.dpi':120})

# Series Originales
fig, axes = plt.subplots(1, 2, sharex=True)
axes[0].plot(medoc_df.value); axes[0].set_title('Series Originales')
plot_acf(medoc_df.value, ax=axes[1])

plt.show()

# %% [markdown]
# ##### Différentiel de 1er ordre

# %%
plt.rcParams.update({'figure.figsize':(9,2), 'figure.dpi':120})


# Différentiel de 1er ordre
fig, axes = plt.subplots(1, 2, sharex=True)

axes[0].plot(medoc_df.value.diff()); axes[0].set_title('Différentiel de 1er ordre')
plot_acf(medoc_df.value.diff().dropna(), ax=axes[1])

plt.show()

# %%
result = adfuller(medoc_df.value.diff().dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -2.495172
# p-value: 0.116653

# %% [markdown]
# La série étant toujours non stationnaire passons à au différentiel de deuxième ordre.

# %% [markdown]
# ##### Différentiel de 2nd ordre

# %%
plt.rcParams.update({'figure.figsize':(9,2), 'figure.dpi':120})

# Différentiel de 2nd ordre
fig, axes = plt.subplots(1, 2, sharex=True)

axes[0].plot(medoc_df.value.diff().diff()); axes[0].set_title('Différentiel de 2nd ordre')
plot_acf(medoc_df.value.diff().diff().dropna(), ax=axes[1])

plt.show()

# %%
result = adfuller(medoc_df.value.diff().diff().dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -10.292305
# p-value: 0.000000

# %% [markdown]
# La série chronologique est desormais stationnaire.

# %% [markdown]
# #### **2 - Comment trouver l'ordre du terme AR (p) ?**
# L'étape suivante consiste à déterminer si le modèle nécessite des termes AR. Nous trouverons le nombre requis de termes AR en inspectant le graphique d'autocorrélation partielle (PACF).
# L'autocorrélation partielle peut être imaginée comme la corrélation entre la série et son retard, après avoir exclu les contributions des retards intermédiaires. Ainsi, le PACF traduit en quelque sorte la corrélation pure entre un retard et la série. De cette façon, nous saurons si ce retard est nécessaire dans le terme AR ou non.
# L'autocorrélation partielle du retard (k) d'une série est le coefficient de ce retard dans l'équation d'autorégression de Y.

# %%
# Plot PACF de la première série différentiée
plt.rcParams.update({'figure.figsize':(9,2), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=True)
axes[0].plot(medoc_df.value.diff()); axes[0].set_title('Différentiel de 1er ordre')
axes[1].set(ylim=(0,5))
plot_pacf(medoc_df.value.diff().dropna(), ax=axes[1])

plt.show()

# %% [markdown]
# Nous pouvons voir que le PACF lag 1 est assez significatif puisqu'il est bien au-dessus de la ligne de signification. Nous allons donc fixer la valeur de p à 1.

# %% [markdown]
# #### **3 - Comment trouver l'ordre du terme MA (q)**
#
# Tout comme nous avons examiné le graphique PACF pour le nombre de termes AR, nous allons examiner le graphique ACF pour le nombre de termes MA. Un terme MA est techniquement, l'erreur de la prévision retardée.
#
# L'ACF indique combien de termes MA sont nécessaires pour éliminer toute autocorrélation dans la série stationnarisée.
#
# Voyons le graphique d'autocorrélation de la série différentiée.

# %%
plt.rcParams.update({'figure.figsize':(9,2), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=True)
axes[0].plot(medoc_df.value.diff()); axes[0].set_title('1er différentiel')
axes[1].set(ylim=(0,1.2))
plot_acf(medoc_df.value.diff().dropna(), ax=axes[1])

plt.show()

# %% [markdown]
# Nous pouvons voir que quelques retards sont bien au-dessus de la ligne de signification. Nous fixerons donc q à 2. En cas de doute, nous opterons pour le modèle le plus simple qui explique suffisamment le Y.

# %% [markdown]
# #### **4 - Construction du modèle ARIMA**
#
# Maintenant, que nous avons déterminé les valeurs de p, d et q. Nous avons tout ce qu'il faut pour ajuster le modèle ARIMA. Nous allons utiliser l'implémentation ARIMA() du paquetage statsmodels.

# %%
#!pip3 install pyramid-arima 
from statsmodels.tsa.arima_model import ARIMA
# 1,1,2 ARIMA Model
model = ARIMA(df.value, order=(1,1,2))
model_fit = model.fit(disp=0)
print(model_fit.summary().tables[0])
print(model_fit.summary().tables[1])

# %% [markdown]
# Le coefficient du terme MA2 est proche de zéro et la valeur P dans la colonne 'P>|z|' est hautement insignifiante. Idéalement, elle devrait être inférieure à 0,05 pour que le X respectif soit significatif.
#
# Nous allons donc reconstruire le modèle sans le terme MA2.

# %%
# 1,1,1 ARIMA Model
model = ARIMA(df.value, order=(1,1,1))
model_fit = model.fit(disp=0)
print(model_fit.summary().tables[0])
print(model_fit.summary().tables[1])

# %% [markdown]
# L'AIC du modèle a légèrement diminué, ce qui est bon. Les p-values des termes AR1 et MA1 se sont améliorées et sont désormais < 0,05.
#
# Traçons les résidus pour nous assurer qu'il n'y a pas de modèle (c'est-à-dire, cherchons une moyenne et une variance constantes).

# %%
# Plot residual errors
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", color ='g', ax=ax[0])
residuals.plot(kind='kde', color ='g',title='Density', ax=ax[1])
plt.show()

# %% [markdown]
# Les erreurs résiduelles semblent correctes avec une moyenne proche de zéro et une variance uniforme. Traçons les valeurs réelles par rapport aux valeurs ajustées en utilisant plot_predict().

# %%
# Réel vs ajusté
model_fit.plot_predict(dynamic=False)
plt.show()

# %% [markdown]
# Nous avons un modèle ARIMA acceptable. Sauf nous ne pouvons pas dire qu'il s'agit du meilleur modèle ARIMA car nous n'avons pas réellement fait de prévisions dans le futur et comparé les prévisions avec les performances réelles.
#
# Ainsi, la véritable validation dont nous avons besoin maintenant est la validation croisée hors du temps.
#
# Pour ce faire, nous devons l'utiliser sur l'ensemble de données de formation et de test diviser au préable en deux parties de séries temporelles contiguës dans une proportion raisonnable basée sur la fréquence temporelle pour la prévions et tracer cela

# %%
# Construction du modèle
# model = ARIMA(train, order=(3,2,1))  
model = ARIMA(train, order=(1, 1, 1))  
fitted = model.fit(disp=-1)  

# Prévision
fc, se, conf = fitted.forecast(len(test), alpha=0.05)  # 95% conf

# Sauvegarder dans une série pandas
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# Traçons
plt.figure(figsize=(11,3), dpi=100)
plt.plot(train, label='Formation')
plt.plot(test, label='Réel')
plt.plot(fc_series, label='Prévision')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Prévision et Réalité')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %% [markdown]
# D'après le graphique ci-dessus, le modèle ARIMA(1,1,1) semble prévoir une prévision correcte. Les valeurs réelles observées se situent dans la bande de confiance de 95%.
#
# Mais, nous pouvons voir que les prévisions prédites sont constamment inférieures aux valeurs réelles. Cela signifie qu'en ajoutant une petite constante à notre prévision, la Precision sera certainement améliorée.
#
# Donc, dans ce cas, nous devrions augmenter l'ordre de différentiation à deux (d=2) et augmenter itérativement p et q jusqu'à 3 pour voir quel modèle donne le moins d'AIC et aussi chercher un graphique qui donne des réalisations et des prévisions plus proches.
#
# Tout en faisant cela, on garde un œil sur les valeurs P des termes AR et MA dans le résumé du modèle. Elles doivent être proches de zéro, idéalement, inférieures à 0,05.

# %%
# Build Model
model = ARIMA(train, order=(3, 2, 1))  
fitted = model.fit(disp=-1) 
print(fitted.summary().tables[0]) 
print(fitted.summary().tables[1])

# Forecast
fc, se, conf = fitted.forecast(len(test), alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# Plot
plt.figure(figsize=(11,3), dpi=100)
plt.plot(train, label='Formation')
plt.plot(test, label='Réel')
plt.plot(fc_series, label='Prévision')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Prévision et Réalité')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %% [markdown]
# L'AIC est passé de 843 à 716, ce qui est bien mais pas assez. Et à noté aussi que la plupart du temps, les valeurs p des termes X sont inférieures à < 0,05, ce qui est excellent. Donc, dans l'ensemble, ce modèle est acceptable mais calculons sa metrique pour le comparer aux autres déja vu.

# %%
Arima_acc = forcast_accuracy(fc, test.values)
Precision['ARIMA ACC'] =  Arima_acc
Precision

# %% [markdown]
# ### <a name="SARIMAForecast">d - SARIMA Forecast
#
# Le modèle ARIMA ordinaire a un problème, il ne supporte pas la saisonnalité.
#
# Si la série temporelle a une saisonnalité définie, nous devons opter pour le modèle ARIMA saisonnier (en abrégé SARIMA) qui utilise la différenciation saisonnière.
#
# La différenciation saisonnière est similaire à la différenciation ordinaire, mais, au lieu de soustraire des termes consécutifs, nous soustrayons la valeur de la saison précédente.
#
# Ainsi, le modèle sera représenté par SARIMA (p, d, q) x (P, D, Q), où P, D et Q sont respectivement les termes SAR, l'ordre de la différenciation saisonnière et SMA et 'x' est la fréquence de la série temporelle. Si le modèle présente des modèles saisonniers bien définis, il faut appliquer D=1 pour une fréquence 'x' donnée.
#
# Nous devrions définir les paramètres du modèle de sorte que D ne dépasse jamais un. Et le différentiel total 'd + D' ne dépasse jamais 2. Nous devons essayer de ne conserver que les termes SAR ou SMA si le modèle comporte des composantes saisonnières.
#
# Maintenant, nous allons construire un modèle SARIMA sur l'ensemble de données de séries temporelles.

# %%
# Plot
fig, axes = plt.subplots(2, 1, figsize=(10,5), dpi=100, sharex=True)

# Différenciation habituelle
axes[0].plot(df, label='Series Originales')
axes[0].plot(df.diff(1), label='Différenciation habituelle', color='black')
axes[0].set_title('Différenciation habituelle')
axes[0].legend(loc='upper left', fontsize=10)


# Différenciation saisonnière
axes[1].plot(df, label='Series Originales')
axes[1].plot(df.diff(12), label='Différenciation saisonnière', color='red')
axes[1].set_title('Différenciation saisonnière')
plt.legend(loc='upper left', fontsize=10)
plt.suptitle('Séries chronologiques de données de Ventes de médicaments', fontsize=16)
plt.show()

# %% [markdown]
# Nous pouvons voir que les pics saisonniers sont intacts après avoir appliqué la différenciation habituelle (lag 1). Alors qu'ils sont rectifiés après la différenciation saisonnière.
#
# Maintenant, construisons le modèle SARIMA en utilisant auto_arima() de pmdarima. Pour ce faire, nous devons définir seasonal=True, définir la fréquence m=12 pour les séries mensuelles et appliquer D=1.

# %%
# Seasonal - fit stepwise auto-ARIMA
#%%capture
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.2-cp39-cp39-macosx_10_9_x86_64.whl (608 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.3/608.3 kB 849.4 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.21.2 in /opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.21.5)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (63.4.1)
# Requirement already satisfied: scipy>=1.3.2 in /opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.10.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (0.29.32)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: pandas>=0.19 in /opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.4.4)
# Requirement already satisfied: statsmodels>=0.13.2 in /opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (0.13.2)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: urllib3 in /opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.26.11)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.19->pmdarima) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /opt/anaconda3/lib/python3.9/site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/lib/python3.9/site-packages (from statsmodels>=0.13.2->pmdarima) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima) (3.0.9)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.0.2

# %%
import pmdarima as pm
sarima_model = pm.auto_arima(df, start_p=1, start_q=1,
                         test='adf',
                         max_p=3, max_q=3, m=12,
                         start_P=0, seasonal=True,
                         d=None, D=1, trace=True,
                         error_action='ignore',  
                         suppress_warnings=True, 
                         stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=534.818, Time=1.50 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=624.061, Time=0.05 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=596.068, Time=0.58 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=611.475, Time=0.36 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=757.274, Time=0.05 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=559.407, Time=0.32 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=inf, Time=1.87 sec
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=536.817, Time=3.11 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=543.106, Time=1.09 sec
#  ARIMA(1,0,1)(1,1,2)[12] intercept   : AIC=537.496, Time=4.56 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=594.467, Time=0.32 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=529.829, Time=1.14 sec
#  ARIMA(2,0,1)(0,1,0)[12] intercept   : AIC=555.198, Time=0.47 sec
#  ARIMA(2,0,1)(1,1,1)[12] intercept   : AIC=inf, Time=2.42 sec
#  ARIMA(2,0,1)(0,1,2)[12] intercept   : AIC=531.168, Time=3.73 sec
#  ARIMA(2,0,1)(1,1,0)[12] intercept   : AIC=534.757, Time=0.98 sec
#  ARIMA(2,0,1)(1,1,2)[12] intercept   : AIC=inf, Time=4.60 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=546.662, Time=0.39 sec
#  ARIMA(3,0,1)(0,1,1)[12] intercept   : AIC=529.107, Time=0.96 sec
#  ARIMA(3,0,1)(0,1,0)[12] intercept   : AIC=549.759, Time=0.55 sec
#  ARIMA(3,0,1)(1,1,1)[12] intercept   : AIC=inf, Time=3.56 sec
#  ARIMA(3,0,1)(0,1,2)[12] intercept   : AIC=530.574, Time=2.75 sec
#  ARIMA(3,0,1)(1,1,0)[12] intercept   : AIC=534.621, Time=1.70 sec
#  ARIMA(3,0,1)(1,1,2)[12] intercept   : AIC=inf, Time=6.04 sec
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=528.788, Time=0.73 sec
#  ARIMA(3,0,0)(0,1,0)[12] intercept   : AIC=554.152, Time=0.33 sec
#  ARIMA(3,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=3.51 sec
#  ARIMA(3,0,0)(0,1,2)[12] intercept   : AIC=529.704, Time=1.83 sec
#  ARIMA(3,0,0)(1,1,0)[12] intercept   : AIC=533.856, Time=1.44 sec
#  ARIMA(3,0,0)(1,1,2)[12] intercept   : AIC=inf, Time=5.19 sec
#  ARIMA(3,0,0)(0,1,1)[12]             : AIC=532.348, Time=0.58 sec
#
# Best model:  ARIMA(3,0,0)(0,1,1)[12] intercept
# Total fit time: 56.758 seconds
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  204
# Model:             SARIMAX(3, 0, 0)x(0, 1, [1], 12)   Log Likelihood                -258.394
# Date:                              Mon, 23 Jan 2023   AIC                            528.788
# Time:                                      18:58:10   BIC                            548.333
# Sample:                                  07-01-1991   HQIC                           536.704
#                                        - 06-01-2008
# Covariance Type:                                opg
# ============================================================================================
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.1638      0.097      1.696      0.090      -0.026       0.353
# ar.L1          0.0960      0.043      2.228      0.026       0.012       0.180
# ar.L2          0.4148      0.035     11.921      0.000       0.347       0.483
# ar.L3          0.3510      0.054      6.546      0.000       0.246       0.456
# ma.S.L12      -0.4627      0.058     -7.966      0.000      -0.577      -0.349
# sigma2         0.8470      0.057     14.914      0.000       0.736       0.958
# ==============================================================================

# %%
print(sarima_model.summary().tables[0])
print(sarima_model.summary().tables[1])
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  204
# Model:             SARIMAX(3, 0, 0)x(0, 1, [1], 12)   Log Likelihood                -258.394
# Date:                              Mon, 23 Jan 2023   AIC                            528.788
# Time:                                      18:58:49   BIC                            548.333
# Sample:                                  07-01-1991   HQIC                           536.704
#                                        - 06-01-2008
# Covariance Type:                                opg
# ============================================================================================
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.1638      0.097      1.696      0.090      -0.026       0.353
# ar.L1          0.0960      0.043      2.228      0.026       0.012       0.180
# ar.L2          0.4148      0.035     11.921      0.000       0.347       0.483
# ar.L3          0.3510      0.054      6.546      0.000       0.246       0.456
# ma.S.L12      -0.4627      0.058     -7.966      0.000      -0.577      -0.349
# sigma2         0.8470      0.057     14.914      0.000       0.736       0.958
# ==============================================================================

# %% [markdown]
# Le modèle a estimé l'AIC et les valeurs P des coefficients semblent significatives. Regardons le graphique de diagnostic des résidus.
#
# Le meilleur modèle SARIMAX(1,0,2)x(1,1,2,12) a un AIC de 524.05 et les valeurs P sont bonnes.
#
# Faisons des prévisions pour les 24 prochains mois.

# %%
# Prévisions
n_periods = 24 #len(test)
fitted, confint = sarima_model.predict(n_periods=n_periods, return_conf_int=True)
index_of_fc = pd.date_range(df.index[-1], periods = n_periods, freq='MS')

# Créer des séries pour la visualisation
fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Visualiser
plt.plot(df)
plt.plot(fitted_series, color='darkgreen')
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("SARIMA - Prévision finale des ventes de médicaments - Série chronologique de données")
plt.show()

# %%
sarima_acc = forcast_accuracy(fitted.values, test.values)
Precision['SARIMA ACC'] = sarima_acc
Precision
# Out:
#       NAÏVE ACC  SEMA ACC  ADD_ADD_ACC  ADD_MUL_ACC  MUL_ADD_ACC  MUL_MUL_ACC  \
# RMSE   3.969457  6.142934     3.105467     2.971185     2.648327       2.3696
#
#       SARIMA ACC
# RMSE     5.24135

# %% [markdown]
# # <a name="TimeSeriesModelingwithDeepLearning">4. Modélisation des séries temporelles avec le Deep Learning

# %% [markdown]
# ## <a name="Preprocessing">1 - Prétraitement des données

# %%
# Fenêtre glissante
def get_timeseries(x, n_steps=1):
    x_ts, y_ts = [], []
    for i in range(len(x) - n_steps):
        v = x.iloc[i:(i + n_steps)].values
        x_ts.append(v)
        w = x.iloc[i + n_steps].values
        y_ts.append(w)
    return np.array(x_ts), np.array(y_ts)

# %% [markdown]
# Utilisons la fonction de fenêtre glissante

# %%
n_steps = 3
n_features = 1

# convert to a time series dimension: [samples, n_steps, n_features]
x_train, y_train = get_timeseries(train, n_steps)
x_test, y_test = get_timeseries(test,n_steps)

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
#print()
#for i in range(len(x_train)):
#  print(x_train[i],y_train[i])
# Out:
# (177, 3, 1) (177, 1)
# (21, 3, 1) (21, 1)

# %% [markdown]
# ## <a name="MLP">2 - MLP

# %% [markdown]
# ### <a name="ModelingMLP">a - Modélisation

# %%
# define model
mlp_model = Sequential()
mlp_model.add(Dense(50, activation='relu', input_dim=n_steps))
mlp_model.add(Dense(1))
mlp_model.compile(loss='mean_squared_error', optimizer=Adam(0.001))

# %%
mlp_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                200
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 251
# Trainable params: 251
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### <a name="TrainingMLP">b - Formation

# %%
# Ajustement du modèle
mlp_history = mlp_model.fit(x_train, y_train,epochs=500,batch_size=32,validation_split=0.1,verbose=1,shuffle=False)
# Out:
# Epoch 1/500
# 5/5 [==============================] - 2s 67ms/step - loss: 57.6646 - val_loss: 174.1901
# Epoch 2/500
# 5/5 [==============================] - 0s 17ms/step - loss: 47.2013 - val_loss: 142.3171
# Epoch 3/500
# 5/5 [==============================] - 0s 13ms/step - loss: 38.1908 - val_loss: 114.5797
# Epoch 4/500
# 5/5 [==============================] - 0s 12ms/step - loss: 30.4491 - val_loss: 90.9703
# Epoch 5/500
# 5/5 [==============================] - 0s 13ms/step - loss: 23.9015 - val_loss: 71.1756
# Epoch 6/500
# 5/5 [==============================] - 0s 13ms/step - loss: 18.4528 - val_loss: 54.9003
# Epoch 7/500
# 5/5 [==============================] - 0s 12ms/step - loss: 14.0051 - val_loss: 41.8656
# Epoch 8/500
# 5/5 [==============================] - 0s 13ms/step - loss: 10.4627 - val_loss: 31.7491
# Epoch 9/500
# 5/5 [==============================] - 0s 12ms/step - loss: 7.7348 - val_loss: 24.2273
# Epoch 10/500
# 5/5 [==============================] - 0s 13ms/step - loss: 5.7133 - val_loss: 18.9142
# Epoch 11/500
# 5/5 [==============================] - 0s 13ms/step - loss: 4.2789 - val_loss: 15.3537
# Epoch 12/500
# 5/5 [==============================] - 0s 13ms/step - loss: 3.3046 - val_loss: 13.1307
# Epoch 13/500
# 5/5 [==============================] - 0s 13ms/step - loss: 2.6657 - val_loss: 11.7633
# Epoch 14/500
# 5/5 [==============================] - 0s 12ms/step - loss: 2.2938 - val_loss: 11.1740
# Epoch 15/500
# 5/5 [==============================] - 0s 13ms/step - loss: 2.1268 - val_loss: 11.1295
# Epoch 16/500
# 5/5 [==============================] - 0s 13ms/step - loss: 2.0824 - val_loss: 11.2791
# Epoch 17/500
# 5/5 [==============================] - 0s 12ms/step - loss: 2.0863 - val_loss: 11.4366
# Epoch 18/500
# 5/5 [==============================] - 0s 13ms/step - loss: 2.0983 - val_loss: 11.5196
# Epoch 19/500
# 5/5 [==============================] - 0s 13ms/step - loss: 2.1027 - val_loss: 11.5203
# Epoch 20/500
# 5/5 [==============================] - 0s 15ms/step - loss: 2.0986 - val_loss: 11.4665
# Epoch 21/500
# 5/5 [==============================] - 0s 14ms/step - loss: 2.0902 - val_loss: 11.3917
# Epoch 22/500
# 5/5 [==============================] - 0s 13ms/step - loss: 2.0817 - val_loss: 11.3189
# Epoch 23/500
# 5/5 [==============================] - 0s 12ms/step - loss: 2.0751 - val_loss: 11.2591
# Epoch 24/500
# 5/5 [==============================] - 0s 18ms/step - loss: 2.0704 - val_loss: 11.2148
# Epoch 25/500
# 5/5 [==============================] - 0s 13ms/step - loss: 2.0669 - val_loss: 11.1844
# Epoch 26/500
# 5/5 [==============================] - 0s 12ms/step - loss: 2.0639 - val_loss: 11.1648
# Epoch 27/500
# 5/5 [==============================] - 0s 13ms/step - loss: 2.0610 - val_loss: 11.1530
# Epoch 28/500
# 5/5 [==============================] - 0s 12ms/step - loss: 2.0582 - val_loss: 11.1464
# Epoch 29/500
# 5/5 [==============================] - 0s 13ms/step - loss: 2.0554 - val_loss: 11.1428
# Epoch 30/500
# 5/5 [==============================] - 0s 17ms/step - loss: 2.0526 - val_loss: 11.1411
# Epoch 31/500
# 5/5 [==============================] - 0s 14ms/step - loss: 2.0497 - val_loss: 11.1401
# Epoch 32/500
# 5/5 [==============================] - 0s 19ms/step - loss: 2.0466 - val_loss: 11.1389
# Epoch 33/500
# 5/5 [==============================] - 0s 13ms/step - loss: 2.0431 - val_loss: 11.1373
# Epoch 34/500
# 5/5 [==============================] - 0s 13ms/step - loss: 2.0389 - val_loss: 11.1389
# Epoch 35/500
# 5/5 [==============================] - 0s 13ms/step - loss: 2.0347 - val_loss: 11.1386
# Epoch 36/500
# 5/5 [==============================] - 0s 13ms/step - loss: 2.0310 - val_loss: 11.1299
# Epoch 37/500
# 5/5 [==============================] - 0s 12ms/step - loss: 2.0274 - val_loss: 11.1239
# Epoch 38/500
# 5/5 [==============================] - 0s 13ms/step - loss: 2.0241 - val_loss: 11.1210
# Epoch 39/500
# 5/5 [==============================] - 0s 13ms/step - loss: 2.0206 - val_loss: 11.1210
# Epoch 40/500
# 5/5 [==============================] - 0s 13ms/step - loss: 2.0172 - val_loss: 11.1227
# Epoch 41/500
# 5/5 [==============================] - 0s 13ms/step - loss: 2.0137 - val_loss: 11.1242
# Epoch 42/500
# 5/5 [==============================] - 0s 17ms/step - loss: 2.0103 - val_loss: 11.1246
# Epoch 43/500
# 5/5 [==============================] - 0s 13ms/step - loss: 2.0071 - val_loss: 11.1246
# Epoch 44/500
# 5/5 [==============================] - 0s 13ms/step - loss: 2.0040 - val_loss: 11.1231
# Epoch 45/500
# 5/5 [==============================] - 0s 13ms/step - loss: 2.0011 - val_loss: 11.1212
# Epoch 46/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.9982 - val_loss: 11.1196
# Epoch 47/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.9955 - val_loss: 11.1192
# Epoch 48/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.9929 - val_loss: 11.1196
# Epoch 49/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.9904 - val_loss: 11.1192
# Epoch 50/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.9880 - val_loss: 11.1180
# Epoch 51/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.9855 - val_loss: 11.1175
# Epoch 52/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.9830 - val_loss: 11.1175
# Epoch 53/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.9804 - val_loss: 11.1182
# Epoch 54/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.9779 - val_loss: 11.1166
# Epoch 55/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.9753 - val_loss: 11.1148
# Epoch 56/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.9726 - val_loss: 11.1133
# Epoch 57/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.9697 - val_loss: 11.1083
# Epoch 58/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.9661 - val_loss: 11.0998
# Epoch 59/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.9621 - val_loss: 11.0890
# Epoch 60/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.9592 - val_loss: 11.0825
# Epoch 61/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.9559 - val_loss: 11.0794
# Epoch 62/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.9522 - val_loss: 11.0783
# Epoch 63/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.9491 - val_loss: 11.0735
# Epoch 64/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.9458 - val_loss: 11.0666
# Epoch 65/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.9423 - val_loss: 11.0605
# Epoch 66/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.9389 - val_loss: 11.0544
# Epoch 67/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.9355 - val_loss: 11.0466
# Epoch 68/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.9320 - val_loss: 11.0401
# Epoch 69/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.9285 - val_loss: 11.0360
# Epoch 70/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.9250 - val_loss: 11.0304
# Epoch 71/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.9216 - val_loss: 11.0237
# Epoch 72/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.9181 - val_loss: 11.0173
# Epoch 73/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.9147 - val_loss: 11.0104
# Epoch 74/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.9111 - val_loss: 11.0056
# Epoch 75/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.9076 - val_loss: 10.9993
# Epoch 76/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.9045 - val_loss: 10.9921
# Epoch 77/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.9009 - val_loss: 10.9889
# Epoch 78/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.8973 - val_loss: 10.9812
# Epoch 79/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.8943 - val_loss: 10.9738
# Epoch 80/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.8905 - val_loss: 10.9719
# Epoch 81/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.8871 - val_loss: 10.9644
# Epoch 82/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.8838 - val_loss: 10.9571
# Epoch 83/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.8802 - val_loss: 10.9538
# Epoch 84/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.8762 - val_loss: 10.9528
# Epoch 85/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.8729 - val_loss: 10.9508
# Epoch 86/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.8698 - val_loss: 10.9423
# Epoch 87/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.8664 - val_loss: 10.9288
# Epoch 88/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.8628 - val_loss: 10.9149
# Epoch 89/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.8591 - val_loss: 10.9089
# Epoch 90/500
# 5/5 [==============================] - 0s 18ms/step - loss: 1.8554 - val_loss: 10.9062
# Epoch 91/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.8521 - val_loss: 10.8997
# Epoch 92/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.8485 - val_loss: 10.8914
# Epoch 93/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.8448 - val_loss: 10.8865
# Epoch 94/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.8418 - val_loss: 10.8820
# Epoch 95/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.8383 - val_loss: 10.8776
# Epoch 96/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.8350 - val_loss: 10.8691
# Epoch 97/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.8312 - val_loss: 10.8665
# Epoch 98/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.8280 - val_loss: 10.8599
# Epoch 99/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.8249 - val_loss: 10.8512
# Epoch 100/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.8214 - val_loss: 10.8453
# Epoch 101/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.8180 - val_loss: 10.8409
# Epoch 102/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.8147 - val_loss: 10.8368
# Epoch 103/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.8115 - val_loss: 10.8328
# Epoch 104/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.8083 - val_loss: 10.8266
# Epoch 105/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.8050 - val_loss: 10.8194
# Epoch 106/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.8017 - val_loss: 10.8127
# Epoch 107/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.7985 - val_loss: 10.8076
# Epoch 108/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.7953 - val_loss: 10.8030
# Epoch 109/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.7921 - val_loss: 10.7979
# Epoch 110/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.7890 - val_loss: 10.7921
# Epoch 111/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.7858 - val_loss: 10.7867
# Epoch 112/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.7826 - val_loss: 10.7817
# Epoch 113/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.7795 - val_loss: 10.7758
# Epoch 114/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.7764 - val_loss: 10.7702
# Epoch 115/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.7733 - val_loss: 10.7653
# Epoch 116/500
# 5/5 [==============================] - 0s 31ms/step - loss: 1.7702 - val_loss: 10.7603
# Epoch 117/500
# 5/5 [==============================] - 0s 18ms/step - loss: 1.7671 - val_loss: 10.7554
# Epoch 118/500
# 5/5 [==============================] - 0s 15ms/step - loss: 1.7641 - val_loss: 10.7504
# Epoch 119/500
# 5/5 [==============================] - 0s 15ms/step - loss: 1.7610 - val_loss: 10.7453
# Epoch 120/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.7579 - val_loss: 10.7397
# Epoch 121/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.7549 - val_loss: 10.7339
# Epoch 122/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.7519 - val_loss: 10.7290
# Epoch 123/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.7489 - val_loss: 10.7243
# Epoch 124/500
# 5/5 [==============================] - 0s 45ms/step - loss: 1.7459 - val_loss: 10.7190
# Epoch 125/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.7430 - val_loss: 10.7139
# Epoch 126/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.7400 - val_loss: 10.7092
# Epoch 127/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.7370 - val_loss: 10.7043
# Epoch 128/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.7341 - val_loss: 10.6991
# Epoch 129/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.7312 - val_loss: 10.6940
# Epoch 130/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7282 - val_loss: 10.6891
# Epoch 131/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.7254 - val_loss: 10.6843
# Epoch 132/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.7225 - val_loss: 10.6795
# Epoch 133/500
# 5/5 [==============================] - 0s 30ms/step - loss: 1.7196 - val_loss: 10.6747
# Epoch 134/500
# 5/5 [==============================] - 0s 39ms/step - loss: 1.7167 - val_loss: 10.6697
# Epoch 135/500
# 5/5 [==============================] - 0s 22ms/step - loss: 1.7139 - val_loss: 10.6649
# Epoch 136/500
# 5/5 [==============================] - 0s 21ms/step - loss: 1.7111 - val_loss: 10.6600
# Epoch 137/500
# 5/5 [==============================] - 0s 42ms/step - loss: 1.7084 - val_loss: 10.6551
# Epoch 138/500
# 5/5 [==============================] - 0s 20ms/step - loss: 1.7055 - val_loss: 10.6499
# Epoch 139/500
# 5/5 [==============================] - 0s 15ms/step - loss: 1.7028 - val_loss: 10.6434
# Epoch 140/500
# 5/5 [==============================] - 0s 15ms/step - loss: 1.7000 - val_loss: 10.6369
# Epoch 141/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.6971 - val_loss: 10.6313
# Epoch 142/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.6943 - val_loss: 10.6269
# Epoch 143/500
# 5/5 [==============================] - 0s 24ms/step - loss: 1.6917 - val_loss: 10.6194
# Epoch 144/500
# 5/5 [==============================] - 0s 30ms/step - loss: 1.6895 - val_loss: 10.5989
# Epoch 145/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6849 - val_loss: 10.5723
# Epoch 146/500
# 5/5 [==============================] - 0s 29ms/step - loss: 1.6799 - val_loss: 10.5686
# Epoch 147/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6754 - val_loss: 10.5758
# Epoch 148/500
# 5/5 [==============================] - 0s 23ms/step - loss: 1.6723 - val_loss: 10.5814
# Epoch 149/500
# 5/5 [==============================] - 0s 33ms/step - loss: 1.6705 - val_loss: 10.5770
# Epoch 150/500
# 5/5 [==============================] - 0s 37ms/step - loss: 1.6676 - val_loss: 10.5678
# Epoch 151/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.6648 - val_loss: 10.5555
# Epoch 152/500
# 5/5 [==============================] - 0s 31ms/step - loss: 1.6615 - val_loss: 10.5455
# Epoch 153/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6584 - val_loss: 10.5406
# Epoch 154/500
# 5/5 [==============================] - 0s 22ms/step - loss: 1.6551 - val_loss: 10.5373
# Epoch 155/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.6523 - val_loss: 10.5316
# Epoch 156/500
# 5/5 [==============================] - 0s 41ms/step - loss: 1.6501 - val_loss: 10.5238
# Epoch 157/500
# 5/5 [==============================] - 0s 36ms/step - loss: 1.6468 - val_loss: 10.5172
# Epoch 158/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.6440 - val_loss: 10.5099
# Epoch 159/500
# 5/5 [==============================] - 0s 37ms/step - loss: 1.6411 - val_loss: 10.5027
# Epoch 160/500
# 5/5 [==============================] - 0s 36ms/step - loss: 1.6386 - val_loss: 10.4956
# Epoch 161/500
# 5/5 [==============================] - 0s 30ms/step - loss: 1.6354 - val_loss: 10.4908
# Epoch 162/500
# 5/5 [==============================] - 0s 33ms/step - loss: 1.6328 - val_loss: 10.4831
# Epoch 163/500
# 5/5 [==============================] - 0s 31ms/step - loss: 1.6299 - val_loss: 10.4765
# Epoch 164/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.6274 - val_loss: 10.4717
# Epoch 165/500
# 5/5 [==============================] - 0s 31ms/step - loss: 1.6245 - val_loss: 10.4655
# Epoch 166/500
# 5/5 [==============================] - 0s 66ms/step - loss: 1.6219 - val_loss: 10.4569
# Epoch 167/500
# 5/5 [==============================] - 0s 18ms/step - loss: 1.6190 - val_loss: 10.4503
# Epoch 168/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.6167 - val_loss: 10.4461
# Epoch 169/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.6137 - val_loss: 10.4405
# Epoch 170/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.6113 - val_loss: 10.4335
# Epoch 171/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.6083 - val_loss: 10.4291
# Epoch 172/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.6059 - val_loss: 10.4230
# Epoch 173/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.6032 - val_loss: 10.4164
# Epoch 174/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.6005 - val_loss: 10.4089
# Epoch 175/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.5976 - val_loss: 10.4025
# Epoch 176/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.5953 - val_loss: 10.3972
# Epoch 177/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.5923 - val_loss: 10.3909
# Epoch 178/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.5897 - val_loss: 10.3827
# Epoch 179/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.5872 - val_loss: 10.3731
# Epoch 180/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.5843 - val_loss: 10.3663
# Epoch 181/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.5814 - val_loss: 10.3621
# Epoch 182/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.5789 - val_loss: 10.3551
# Epoch 183/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.5763 - val_loss: 10.3480
# Epoch 184/500
# 5/5 [==============================] - 0s 15ms/step - loss: 1.5741 - val_loss: 10.3407
# Epoch 185/500
# 5/5 [==============================] - 0s 22ms/step - loss: 1.5710 - val_loss: 10.3345
# Epoch 186/500
# 5/5 [==============================] - 0s 18ms/step - loss: 1.5687 - val_loss: 10.3277
# Epoch 187/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.5659 - val_loss: 10.3229
# Epoch 188/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.5637 - val_loss: 10.3138
# Epoch 189/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.5611 - val_loss: 10.3046
# Epoch 190/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.5585 - val_loss: 10.2991
# Epoch 191/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.5554 - val_loss: 10.2983
# Epoch 192/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.5535 - val_loss: 10.2905
# Epoch 193/500
# 5/5 [==============================] - 0s 42ms/step - loss: 1.5509 - val_loss: 10.2787
# Epoch 194/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.5481 - val_loss: 10.2699
# Epoch 195/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.5450 - val_loss: 10.2676
# Epoch 196/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.5428 - val_loss: 10.2620
# Epoch 197/500
# 5/5 [==============================] - 0s 18ms/step - loss: 1.5404 - val_loss: 10.2550
# Epoch 198/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.5377 - val_loss: 10.2472
# Epoch 199/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.5352 - val_loss: 10.2393
# Epoch 200/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.5327 - val_loss: 10.2338
# Epoch 201/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.5300 - val_loss: 10.2293
# Epoch 202/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.5277 - val_loss: 10.2218
# Epoch 203/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.5254 - val_loss: 10.2151
# Epoch 204/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.5224 - val_loss: 10.2146
# Epoch 205/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.5203 - val_loss: 10.2091
# Epoch 206/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.5183 - val_loss: 10.1984
# Epoch 207/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.5156 - val_loss: 10.1898
# Epoch 208/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.5129 - val_loss: 10.1844
# Epoch 209/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.5106 - val_loss: 10.1783
# Epoch 210/500
# 5/5 [==============================] - 0s 20ms/step - loss: 1.5083 - val_loss: 10.1732
# Epoch 211/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.5057 - val_loss: 10.1718
# Epoch 212/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.5037 - val_loss: 10.1644
# Epoch 213/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.5012 - val_loss: 10.1559
# Epoch 214/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.4988 - val_loss: 10.1486
# Epoch 215/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.4965 - val_loss: 10.1409
# Epoch 216/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4940 - val_loss: 10.1342
# Epoch 217/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.4917 - val_loss: 10.1274
# Epoch 218/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.4891 - val_loss: 10.1216
# Epoch 219/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4871 - val_loss: 10.1167
# Epoch 220/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.4847 - val_loss: 10.1122
# Epoch 221/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.4829 - val_loss: 10.1021
# Epoch 222/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4806 - val_loss: 10.0934
# Epoch 223/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.4779 - val_loss: 10.0904
# Epoch 224/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.4754 - val_loss: 10.0885
# Epoch 225/500
# 5/5 [==============================] - 0s 15ms/step - loss: 1.4738 - val_loss: 10.0795
# Epoch 226/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4720 - val_loss: 10.0684
# Epoch 227/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4690 - val_loss: 10.0662
# Epoch 228/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4666 - val_loss: 10.0655
# Epoch 229/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4651 - val_loss: 10.0554
# Epoch 230/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4633 - val_loss: 10.0446
# Epoch 231/500
# 5/5 [==============================] - 0s 15ms/step - loss: 1.4602 - val_loss: 10.0429
# Epoch 232/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.4579 - val_loss: 10.0427
# Epoch 233/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4566 - val_loss: 10.0323
# Epoch 234/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4547 - val_loss: 10.0231
# Epoch 235/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4514 - val_loss: 10.0202
# Epoch 236/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4500 - val_loss: 10.0127
# Epoch 237/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4475 - val_loss: 10.0088
# Epoch 238/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4456 - val_loss: 10.0008
# Epoch 239/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4439 - val_loss: 9.9909
# Epoch 240/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4411 - val_loss: 9.9890
# Epoch 241/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4390 - val_loss: 9.9881
# Epoch 242/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.4376 - val_loss: 9.9784
# Epoch 243/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4358 - val_loss: 9.9687
# Epoch 244/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.4330 - val_loss: 9.9624
# Epoch 245/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4307 - val_loss: 9.9585
# Epoch 246/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4291 - val_loss: 9.9526
# Epoch 247/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.4265 - val_loss: 9.9503
# Epoch 248/500
# 5/5 [==============================] - 0s 15ms/step - loss: 1.4251 - val_loss: 9.9437
# Epoch 249/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.4229 - val_loss: 9.9353
# Epoch 250/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.4212 - val_loss: 9.9264
# Epoch 251/500
# 5/5 [==============================] - 0s 15ms/step - loss: 1.4185 - val_loss: 9.9247
# Epoch 252/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.4165 - val_loss: 9.9213
# Epoch 253/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4149 - val_loss: 9.9156
# Epoch 254/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4128 - val_loss: 9.9078
# Epoch 255/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4110 - val_loss: 9.8980
# Epoch 256/500
# 5/5 [==============================] - 0s 18ms/step - loss: 1.4089 - val_loss: 9.8920
# Epoch 257/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4066 - val_loss: 9.8875
# Epoch 258/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.4048 - val_loss: 9.8806
# Epoch 259/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.4029 - val_loss: 9.8734
# Epoch 260/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.4010 - val_loss: 9.8649
# Epoch 261/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3989 - val_loss: 9.8593
# Epoch 262/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3969 - val_loss: 9.8540
# Epoch 263/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3952 - val_loss: 9.8462
# Epoch 264/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3932 - val_loss: 9.8387
# Epoch 265/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.3913 - val_loss: 9.8309
# Epoch 266/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3892 - val_loss: 9.8255
# Epoch 267/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3873 - val_loss: 9.8201
# Epoch 268/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3857 - val_loss: 9.8109
# Epoch 269/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3838 - val_loss: 9.8050
# Epoch 270/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3814 - val_loss: 9.8028
# Epoch 271/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.3801 - val_loss: 9.7959
# Epoch 272/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3787 - val_loss: 9.7842
# Epoch 273/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.3765 - val_loss: 9.7766
# Epoch 274/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3742 - val_loss: 9.7724
# Epoch 275/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3726 - val_loss: 9.7683
# Epoch 276/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3708 - val_loss: 9.7622
# Epoch 277/500
# 5/5 [==============================] - 0s 15ms/step - loss: 1.3694 - val_loss: 9.7518
# Epoch 278/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.3677 - val_loss: 9.7448
# Epoch 279/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.3653 - val_loss: 9.7425
# Epoch 280/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3635 - val_loss: 9.7384
# Epoch 281/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.3622 - val_loss: 9.7290
# Epoch 282/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3604 - val_loss: 9.7214
# Epoch 283/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.3582 - val_loss: 9.7180
# Epoch 284/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.3566 - val_loss: 9.7125
# Epoch 285/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3553 - val_loss: 9.7024
# Epoch 286/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.3535 - val_loss: 9.6952
# Epoch 287/500
# 5/5 [==============================] - 0s 42ms/step - loss: 1.3512 - val_loss: 9.6929
# Epoch 288/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.3498 - val_loss: 9.6867
# Epoch 289/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3488 - val_loss: 9.6740
# Epoch 290/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3467 - val_loss: 9.6667
# Epoch 291/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3445 - val_loss: 9.6637
# Epoch 292/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3429 - val_loss: 9.6592
# Epoch 293/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3416 - val_loss: 9.6503
# Epoch 294/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.3402 - val_loss: 9.6412
# Epoch 295/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3380 - val_loss: 9.6361
# Epoch 296/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3365 - val_loss: 9.6314
# Epoch 297/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.3350 - val_loss: 9.6244
# Epoch 298/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3336 - val_loss: 9.6163
# Epoch 299/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3317 - val_loss: 9.6116
# Epoch 300/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3298 - val_loss: 9.6092
# Epoch 301/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.3286 - val_loss: 9.6013
# Epoch 302/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3275 - val_loss: 9.5893
# Epoch 303/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.3258 - val_loss: 9.5798
# Epoch 304/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.3239 - val_loss: 9.5737
# Epoch 305/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.3225 - val_loss: 9.5669
# Epoch 306/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3209 - val_loss: 9.5608
# Epoch 307/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.3190 - val_loss: 9.5570
# Epoch 308/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3179 - val_loss: 9.5505
# Epoch 309/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.3165 - val_loss: 9.5417
# Epoch 310/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.3148 - val_loss: 9.5350
# Epoch 311/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3129 - val_loss: 9.5334
# Epoch 312/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.3116 - val_loss: 9.5298
# Epoch 313/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.3108 - val_loss: 9.5215
# Epoch 314/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.3086 - val_loss: 9.5133
# Epoch 315/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3073 - val_loss: 9.5066
# Epoch 316/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3061 - val_loss: 9.4986
# Epoch 317/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.3047 - val_loss: 9.4911
# Epoch 318/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3025 - val_loss: 9.4862
# Epoch 319/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3017 - val_loss: 9.4789
# Epoch 320/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3006 - val_loss: 9.4679
# Epoch 321/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2985 - val_loss: 9.4641
# Epoch 322/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2970 - val_loss: 9.4608
# Epoch 323/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2962 - val_loss: 9.4509
# Epoch 324/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.2947 - val_loss: 9.4424
# Epoch 325/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2929 - val_loss: 9.4390
# Epoch 326/500
# 5/5 [==============================] - 0s 18ms/step - loss: 1.2920 - val_loss: 9.4298
# Epoch 327/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2905 - val_loss: 9.4218
# Epoch 328/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2890 - val_loss: 9.4159
# Epoch 329/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2879 - val_loss: 9.4085
# Epoch 330/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.2864 - val_loss: 9.4027
# Epoch 331/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.2855 - val_loss: 9.3942
# Epoch 332/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2837 - val_loss: 9.3893
# Epoch 333/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.2824 - val_loss: 9.3891
# Epoch 334/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2820 - val_loss: 9.3795
# Epoch 335/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.2809 - val_loss: 9.3676
# Epoch 336/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2791 - val_loss: 9.3597
# Epoch 337/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2775 - val_loss: 9.3558
# Epoch 338/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2764 - val_loss: 9.3528
# Epoch 339/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2755 - val_loss: 9.3462
# Epoch 340/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.2745 - val_loss: 9.3371
# Epoch 341/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2731 - val_loss: 9.3298
# Epoch 342/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.2717 - val_loss: 9.3262
# Epoch 343/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.2705 - val_loss: 9.3220
# Epoch 344/500
# 5/5 [==============================] - 0s 22ms/step - loss: 1.2696 - val_loss: 9.3139
# Epoch 345/500
# 5/5 [==============================] - 0s 15ms/step - loss: 1.2690 - val_loss: 9.3039
# Epoch 346/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.2668 - val_loss: 9.3014
# Epoch 347/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2655 - val_loss: 9.2997
# Epoch 348/500
# 5/5 [==============================] - 0s 18ms/step - loss: 1.2653 - val_loss: 9.2908
# Epoch 349/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2638 - val_loss: 9.2827
# Epoch 350/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2626 - val_loss: 9.2760
# Epoch 351/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2614 - val_loss: 9.2713
# Epoch 352/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.2602 - val_loss: 9.2682
# Epoch 353/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.2592 - val_loss: 9.2635
# Epoch 354/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2583 - val_loss: 9.2550
# Epoch 355/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2573 - val_loss: 9.2455
# Epoch 356/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2555 - val_loss: 9.2419
# Epoch 357/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2544 - val_loss: 9.2377
# Epoch 358/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.2540 - val_loss: 9.2284
# Epoch 359/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2533 - val_loss: 9.2190
# Epoch 360/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2511 - val_loss: 9.2150
# Epoch 361/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.2501 - val_loss: 9.2091
# Epoch 362/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2497 - val_loss: 9.1993
# Epoch 363/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2482 - val_loss: 9.1918
# Epoch 364/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2470 - val_loss: 9.1846
# Epoch 365/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.2465 - val_loss: 9.1716
# Epoch 366/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.2453 - val_loss: 9.1625
# Epoch 367/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2430 - val_loss: 9.1527
# Epoch 368/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2429 - val_loss: 9.1333
# Epoch 369/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2422 - val_loss: 9.1166
# Epoch 370/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2401 - val_loss: 9.1094
# Epoch 371/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2396 - val_loss: 9.1041
# Epoch 372/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.2386 - val_loss: 9.1016
# Epoch 373/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2373 - val_loss: 9.0999
# Epoch 374/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.2363 - val_loss: 9.0932
# Epoch 375/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2358 - val_loss: 9.0852
# Epoch 376/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2340 - val_loss: 9.0809
# Epoch 377/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.2338 - val_loss: 9.0722
# Epoch 378/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2333 - val_loss: 9.0630
# Epoch 379/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2315 - val_loss: 9.0593
# Epoch 380/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.2303 - val_loss: 9.0567
# Epoch 381/500
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2298 - val_loss: 9.0519
# Epoch 382/500
# 5/5 [==============================] - 0s 41ms/step - loss: 1.2294 - val_loss: 9.0457
# Epoch 383/500
# 5/5 [==============================] - 0s 42ms/step - loss: 1.2272 - val_loss: 9.0427
# Epoch 384/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.2270 - val_loss: 9.0365
# Epoch 385/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.2264 - val_loss: 9.0281
# Epoch 386/500
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2250 - val_loss: 9.0237
# Epoch 387/500
# 5/5 [==============================] - 0s 15ms/step - loss: 1.2239 - val_loss: 9.0198
# Epoch 388/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2234 - val_loss: 9.0116
# Epoch 389/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.2228 - val_loss: 9.0032
# Epoch 390/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2211 - val_loss: 8.9989
# Epoch 391/500
# 5/5 [==============================] - 0s 12ms/step - loss: 1.2202 - val_loss: 8.9973
# Epoch 392/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2200 - val_loss: 8.9904
# Epoch 393/500
# 5/5 [==============================] - 0s 48ms/step - loss: 1.2188 - val_loss: 8.9837
# Epoch 394/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.2179 - val_loss: 8.9776
# Epoch 395/500
# 5/5 [==============================] - 0s 42ms/step - loss: 1.2165 - val_loss: 8.9735
# Epoch 396/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.2163 - val_loss: 8.9679
# Epoch 397/500
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2156 - val_loss: 8.9609
# Epoch 398/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.2140 - val_loss: 8.9578
# Epoch 399/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2135 - val_loss: 8.9544
# Epoch 400/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2124 - val_loss: 8.9500
# Epoch 401/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2116 - val_loss: 8.9428
# Epoch 402/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.2111 - val_loss: 8.9359
# Epoch 403/500
# 5/5 [==============================] - 0s 29ms/step - loss: 1.2096 - val_loss: 8.9334
# Epoch 404/500
# 5/5 [==============================] - 0s 39ms/step - loss: 1.2089 - val_loss: 8.9277
# Epoch 405/500
# 5/5 [==============================] - 0s 55ms/step - loss: 1.2083 - val_loss: 8.9194
# Epoch 406/500
# 5/5 [==============================] - 0s 18ms/step - loss: 1.2070 - val_loss: 8.9138
# Epoch 407/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.2065 - val_loss: 8.9094
# Epoch 408/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.2057 - val_loss: 8.9027
# Epoch 409/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2046 - val_loss: 8.8973
# Epoch 410/500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.2039 - val_loss: 8.8931
# Epoch 411/500
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2027 - val_loss: 8.8886
# Epoch 412/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.2022 - val_loss: 8.8815
# Epoch 413/500
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2017 - val_loss: 8.8744
# Epoch 414/500
# 5/5 [==============================] - 0s 47ms/step - loss: 1.2002 - val_loss: 8.8724
# Epoch 415/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.1997 - val_loss: 8.8669
# Epoch 416/500
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1991 - val_loss: 8.8584
# Epoch 417/500
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1977 - val_loss: 8.8531
# Epoch 418/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.1972 - val_loss: 8.8501
# Epoch 419/500
# 5/5 [==============================] - 0s 22ms/step - loss: 1.1965 - val_loss: 8.8438
# Epoch 420/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.1955 - val_loss: 8.8363
# Epoch 421/500
# 5/5 [==============================] - 0s 59ms/step - loss: 1.1949 - val_loss: 8.8299
# Epoch 422/500
# 5/5 [==============================] - 0s 30ms/step - loss: 1.1938 - val_loss: 8.8273
# Epoch 423/500
# 5/5 [==============================] - 0s 38ms/step - loss: 1.1933 - val_loss: 8.8207
# Epoch 424/500
# 5/5 [==============================] - 0s 33ms/step - loss: 1.1927 - val_loss: 8.8138
# Epoch 425/500
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1913 - val_loss: 8.8100
# Epoch 426/500
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1911 - val_loss: 8.8052
# Epoch 427/500
# 5/5 [==============================] - 0s 49ms/step - loss: 1.1905 - val_loss: 8.7970
# Epoch 428/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.1893 - val_loss: 8.7900
# Epoch 429/500
# 5/5 [==============================] - 0s 23ms/step - loss: 1.1886 - val_loss: 8.7866
# Epoch 430/500
# 5/5 [==============================] - 0s 59ms/step - loss: 1.1876 - val_loss: 8.7835
# Epoch 431/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.1874 - val_loss: 8.7769
# Epoch 432/500
# 5/5 [==============================] - 0s 40ms/step - loss: 1.1867 - val_loss: 8.7685
# Epoch 433/500
# 5/5 [==============================] - 0s 45ms/step - loss: 1.1853 - val_loss: 8.7658
# Epoch 434/500
# 5/5 [==============================] - 0s 30ms/step - loss: 1.1851 - val_loss: 8.7602
# Epoch 435/500
# 5/5 [==============================] - 0s 24ms/step - loss: 1.1847 - val_loss: 8.7536
# Epoch 436/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.1832 - val_loss: 8.7481
# Epoch 437/500
# 5/5 [==============================] - 0s 18ms/step - loss: 1.1829 - val_loss: 8.7409
# Epoch 438/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.1823 - val_loss: 8.7375
# Epoch 439/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.1812 - val_loss: 8.7343
# Epoch 440/500
# 5/5 [==============================] - 0s 36ms/step - loss: 1.1809 - val_loss: 8.7257
# Epoch 441/500
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1798 - val_loss: 8.7223
# Epoch 442/500
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1796 - val_loss: 8.7184
# Epoch 443/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.1788 - val_loss: 8.7098
# Epoch 444/500
# 5/5 [==============================] - 0s 18ms/step - loss: 1.1776 - val_loss: 8.7027
# Epoch 445/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.1774 - val_loss: 8.6973
# Epoch 446/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.1766 - val_loss: 8.6939
# Epoch 447/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.1759 - val_loss: 8.6907
# Epoch 448/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.1751 - val_loss: 8.6838
# Epoch 449/500
# 5/5 [==============================] - 0s 24ms/step - loss: 1.1747 - val_loss: 8.6782
# Epoch 450/500
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1743 - val_loss: 8.6726
# Epoch 451/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.1732 - val_loss: 8.6681
# Epoch 452/500
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1722 - val_loss: 8.6622
# Epoch 453/500
# 5/5 [==============================] - 0s 18ms/step - loss: 1.1720 - val_loss: 8.6584
# Epoch 454/500
# 5/5 [==============================] - 0s 30ms/step - loss: 1.1712 - val_loss: 8.6544
# Epoch 455/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.1704 - val_loss: 8.6472
# Epoch 456/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.1696 - val_loss: 8.6421
# Epoch 457/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.1682 - val_loss: 8.6377
# Epoch 458/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.1679 - val_loss: 8.6280
# Epoch 459/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.1666 - val_loss: 8.6220
# Epoch 460/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.1649 - val_loss: 8.6198
# Epoch 461/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.1640 - val_loss: 8.6186
# Epoch 462/500
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1636 - val_loss: 8.6141
# Epoch 463/500
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1623 - val_loss: 8.6066
# Epoch 464/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.1612 - val_loss: 8.5998
# Epoch 465/500
# 5/5 [==============================] - 0s 18ms/step - loss: 1.1610 - val_loss: 8.5954
# Epoch 466/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.1597 - val_loss: 8.5954
# Epoch 467/500
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1591 - val_loss: 8.5937
# Epoch 468/500
# 5/5 [==============================] - 0s 18ms/step - loss: 1.1587 - val_loss: 8.5873
# Epoch 469/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.1579 - val_loss: 8.5851
# Epoch 470/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.1570 - val_loss: 8.5829
# Epoch 471/500
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1568 - val_loss: 8.5760
# Epoch 472/500
# 5/5 [==============================] - 0s 52ms/step - loss: 1.1561 - val_loss: 8.5719
# Epoch 473/500
# 5/5 [==============================] - 0s 18ms/step - loss: 1.1555 - val_loss: 8.5685
# Epoch 474/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.1551 - val_loss: 8.5627
# Epoch 475/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.1545 - val_loss: 8.5570
# Epoch 476/500
# 5/5 [==============================] - 0s 18ms/step - loss: 1.1535 - val_loss: 8.5495
# Epoch 477/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.1534 - val_loss: 8.5438
# Epoch 478/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.1530 - val_loss: 8.5397
# Epoch 479/500
# 5/5 [==============================] - 0s 18ms/step - loss: 1.1522 - val_loss: 8.5362
# Epoch 480/500
# 5/5 [==============================] - 0s 18ms/step - loss: 1.1517 - val_loss: 8.5334
# Epoch 481/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.1511 - val_loss: 8.5308
# Epoch 482/500
# 5/5 [==============================] - 0s 22ms/step - loss: 1.1505 - val_loss: 8.5286
# Epoch 483/500
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1502 - val_loss: 8.5247
# Epoch 484/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.1499 - val_loss: 8.5163
# Epoch 485/500
# 5/5 [==============================] - 0s 18ms/step - loss: 1.1488 - val_loss: 8.5135
# Epoch 486/500
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1490 - val_loss: 8.5080
# Epoch 487/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.1486 - val_loss: 8.5030
# Epoch 488/500
# 5/5 [==============================] - 0s 33ms/step - loss: 1.1478 - val_loss: 8.4995
# Epoch 489/500
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1468 - val_loss: 8.4963
# Epoch 490/500
# 5/5 [==============================] - 0s 18ms/step - loss: 1.1470 - val_loss: 8.4925
# Epoch 491/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.1459 - val_loss: 8.4906
# Epoch 492/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.1461 - val_loss: 8.4856
# Epoch 493/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.1454 - val_loss: 8.4816
# Epoch 494/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.1447 - val_loss: 8.4775
# Epoch 495/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.1445 - val_loss: 8.4729
# Epoch 496/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.1439 - val_loss: 8.4684
# Epoch 497/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.1432 - val_loss: 8.4638
# Epoch 498/500
# 5/5 [==============================] - 0s 18ms/step - loss: 1.1426 - val_loss: 8.4594
# Epoch 499/500
# 5/5 [==============================] - 0s 31ms/step - loss: 1.1429 - val_loss: 8.4539
# Epoch 500/500
# 5/5 [==============================] - 0s 19ms/step - loss: 1.1420 - val_loss: 8.4494

# %% [markdown]
# ### <a name="EvaluationMLP">c - Evaluation

# %%
y_predmlp = mlp_model.predict(x_test)
# Out:
# 1/1 [==============================] - 0s 134ms/step

# %%
print("Données de Test\t\tDonnées prédites")
for i in range(len(y_test )):
    print(f"{y_test[i]}\t\t{y_predmlp[i]}")
# Out:
# Données de Test		Données prédites
# [21.430241]		[18.842709]
# [23.575517]		[19.95959]
# [23.334206]		[13.698783]
# [28.038383]		[23.407888]
# [16.763869]		[24.260986]
# [19.792754]		[19.773275]
# [16.427305]		[19.753572]
# [21.000742]		[18.692673]
# [20.681002]		[20.871763]
# [21.83489]		[15.369942]
# [23.93020353]		[23.28588]
# [22.93035694]		[21.772112]
# [23.26333992]		[24.453161]
# [25.25003022]		[25.605257]
# [25.80609]		[24.989426]
# [29.665356]		[25.044006]
# [21.654285]		[26.114742]
# [18.264945]		[25.013502]
# [23.107677]		[19.019064]
# [22.91251]		[22.932896]
# [19.43174]		[17.095821]

# %%
# Visualisation
plt.plot(np.arange(0, len(y_train)), y_train, 'g', label="History")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test, marker='.', label="Données Actuelles")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_predmlp, 'r', label="Prédiction")
plt.ylabel('Détail de vente')
plt.xlabel('Période')
plt.legend()
plt.show();

# %%
# Visualisation de la prédiction
forecast_plot(forecast_data = y_test, forecast_label = 'MLP Forecast',test_time=test_time[3:],test_data=y_predmlp)

# %%
# Accuracy
#mlp_train_result = forcast_accuracy(train_Precision_rescale,train_label_rescale)
mlp_forecast = forcast_accuracy(y_predmlp,y_test)
#print('Train Score: %.2f RMSE' % (mlp_train_result))
#print('Test Score: %.2f RMSE' % (mlp_forecast_result))

Precision['MLP ACC'] =  mlp_forecast
Precision
# Out:
#       NAÏVE ACC  SEMA ACC  ADD_ADD_ACC  ADD_MUL_ACC  MUL_ADD_ACC  MUL_MUL_ACC  \
# RMSE   3.969457  6.142934     3.105467     2.971185     2.648327       2.3696
#
#       SARIMA ACC   MLP ACC
# RMSE     5.24135  4.148541

# %% [markdown]
# ## <a name="LSTM">3 - LSTM

# %% [markdown]
# ### <a name="ModelingLSTM">a - Modélisation

# %%
# define model
lstm_model = Sequential()
lstm_model.add(LSTM(units=256, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))
#model.add(Dense(100, activation='relu'))
lstm_model.add(Dense(1))
lstm_model.compile(loss='mean_squared_error',optimizer=Adam(0.001))

# %%
lstm_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 256)               264192
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 264,449
# Trainable params: 264,449
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### <a name="FormationLSTM">b - Formation

# %%
# fit model
lstm_history = lstm_model.fit(x_train, y_train,epochs=500,batch_size=32,validation_split=0.1,verbose=1,shuffle=False)
# Out:
# Epoch 1/500
# 5/5 [==============================] - 3s 119ms/step - loss: 78.3932 - val_loss: 230.8194
# Epoch 2/500
# 5/5 [==============================] - 0s 27ms/step - loss: 63.3124 - val_loss: 175.4239
# Epoch 3/500
# 5/5 [==============================] - 0s 27ms/step - loss: 47.3934 - val_loss: 109.7519
# Epoch 4/500
# 5/5 [==============================] - 0s 27ms/step - loss: 28.8861 - val_loss: 39.1016
# Epoch 5/500
# 5/5 [==============================] - 0s 27ms/step - loss: 11.3123 - val_loss: 44.7976
# Epoch 6/500
# 5/5 [==============================] - 0s 27ms/step - loss: 13.9900 - val_loss: 178.3774
# Epoch 7/500
# 5/5 [==============================] - 0s 27ms/step - loss: 8.5891 - val_loss: 95.0212
# Epoch 8/500
# 5/5 [==============================] - 0s 27ms/step - loss: 5.6147 - val_loss: 37.8280
# Epoch 9/500
# 5/5 [==============================] - 0s 27ms/step - loss: 6.9122 - val_loss: 26.5657
# Epoch 10/500
# 5/5 [==============================] - 0s 27ms/step - loss: 6.8879 - val_loss: 30.3404
# Epoch 11/500
# 5/5 [==============================] - 0s 32ms/step - loss: 6.0659 - val_loss: 44.1530
# Epoch 12/500
# 5/5 [==============================] - 0s 27ms/step - loss: 5.8406 - val_loss: 56.1207
# Epoch 13/500
# 5/5 [==============================] - 0s 26ms/step - loss: 5.4915 - val_loss: 50.9132
# Epoch 14/500
# 5/5 [==============================] - 0s 27ms/step - loss: 5.0245 - val_loss: 38.9462
# Epoch 15/500
# 5/5 [==============================] - 0s 26ms/step - loss: 4.9245 - val_loss: 32.5411
# Epoch 16/500
# 5/5 [==============================] - 0s 26ms/step - loss: 4.8343 - val_loss: 31.9330
# Epoch 17/500
# 5/5 [==============================] - 0s 27ms/step - loss: 4.6498 - val_loss: 33.4512
# Epoch 18/500
# 5/5 [==============================] - 0s 26ms/step - loss: 4.4462 - val_loss: 32.9356
# Epoch 19/500
# 5/5 [==============================] - 0s 26ms/step - loss: 4.2157 - val_loss: 29.6166
# Epoch 20/500
# 5/5 [==============================] - 0s 27ms/step - loss: 4.0239 - val_loss: 26.1773
# Epoch 21/500
# 5/5 [==============================] - 0s 26ms/step - loss: 3.8710 - val_loss: 24.0824
# Epoch 22/500
# 5/5 [==============================] - 0s 27ms/step - loss: 3.7113 - val_loss: 22.7988
# Epoch 23/500
# 5/5 [==============================] - 0s 26ms/step - loss: 3.5409 - val_loss: 21.2742
# Epoch 24/500
# 5/5 [==============================] - 0s 26ms/step - loss: 3.3751 - val_loss: 19.4227
# Epoch 25/500
# 5/5 [==============================] - 0s 26ms/step - loss: 3.2270 - val_loss: 17.7673
# Epoch 26/500
# 5/5 [==============================] - 0s 26ms/step - loss: 3.0927 - val_loss: 16.4666
# Epoch 27/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.9664 - val_loss: 15.2870
# Epoch 28/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.8512 - val_loss: 14.1491
# Epoch 29/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.7526 - val_loss: 13.1864
# Epoch 30/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.6688 - val_loss: 12.4410
# Epoch 31/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.5993 - val_loss: 11.8185
# Epoch 32/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.5459 - val_loss: 11.3724
# Epoch 33/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.5078 - val_loss: 11.0566
# Epoch 34/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.4811 - val_loss: 10.8546
# Epoch 35/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.4618 - val_loss: 10.7194
# Epoch 36/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.4490 - val_loss: 10.6039
# Epoch 37/500
# 5/5 [==============================] - 0s 31ms/step - loss: 2.4359 - val_loss: 10.5261
# Epoch 38/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.4258 - val_loss: 10.4945
# Epoch 39/500
# 5/5 [==============================] - 0s 31ms/step - loss: 2.4145 - val_loss: 10.4551
# Epoch 40/500
# 5/5 [==============================] - 0s 28ms/step - loss: 2.4038 - val_loss: 10.4089
# Epoch 41/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.3924 - val_loss: 10.3508
# Epoch 42/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.3823 - val_loss: 10.3367
# Epoch 43/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.3744 - val_loss: 10.3295
# Epoch 44/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.3576 - val_loss: 10.2650
# Epoch 45/500
# 5/5 [==============================] - 0s 31ms/step - loss: 2.3542 - val_loss: 10.2700
# Epoch 46/500
# 5/5 [==============================] - 0s 29ms/step - loss: 2.3405 - val_loss: 10.2323
# Epoch 47/500
# 5/5 [==============================] - 0s 28ms/step - loss: 2.3337 - val_loss: 10.2221
# Epoch 48/500
# 5/5 [==============================] - 0s 28ms/step - loss: 2.3230 - val_loss: 10.1877
# Epoch 49/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.3162 - val_loss: 10.1777
# Epoch 50/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.3078 - val_loss: 10.1590
# Epoch 51/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.2999 - val_loss: 10.1423
# Epoch 52/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.2927 - val_loss: 10.1240
# Epoch 53/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.2865 - val_loss: 10.1185
# Epoch 54/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.2788 - val_loss: 10.0972
# Epoch 55/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.2749 - val_loss: 10.1033
# Epoch 56/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.2655 - val_loss: 10.0634
# Epoch 57/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.2631 - val_loss: 10.0914
# Epoch 58/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.2535 - val_loss: 10.0601
# Epoch 59/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.2505 - val_loss: 10.0617
# Epoch 60/500
# 5/5 [==============================] - 0s 30ms/step - loss: 2.2451 - val_loss: 10.0584
# Epoch 61/500
# 5/5 [==============================] - 0s 30ms/step - loss: 2.2396 - val_loss: 10.0484
# Epoch 62/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.2348 - val_loss: 10.0474
# Epoch 63/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.2309 - val_loss: 10.0337
# Epoch 64/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.2277 - val_loss: 10.0593
# Epoch 65/500
# 5/5 [==============================] - 0s 25ms/step - loss: 2.2207 - val_loss: 10.0388
# Epoch 66/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.2184 - val_loss: 10.0412
# Epoch 67/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.2147 - val_loss: 10.0244
# Epoch 68/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.2117 - val_loss: 10.0577
# Epoch 69/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.2052 - val_loss: 10.0308
# Epoch 70/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.2039 - val_loss: 10.0490
# Epoch 71/500
# 5/5 [==============================] - 0s 25ms/step - loss: 2.1993 - val_loss: 10.0354
# Epoch 72/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1966 - val_loss: 10.0408
# Epoch 73/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1933 - val_loss: 10.0572
# Epoch 74/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1889 - val_loss: 10.0306
# Epoch 75/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1887 - val_loss: 10.0152
# Epoch 76/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1862 - val_loss: 10.0568
# Epoch 77/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.1787 - val_loss: 10.0404
# Epoch 78/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1786 - val_loss: 10.0525
# Epoch 79/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.1752 - val_loss: 10.0383
# Epoch 80/500
# 5/5 [==============================] - 0s 25ms/step - loss: 2.1722 - val_loss: 10.0327
# Epoch 81/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1697 - val_loss: 10.0429
# Epoch 82/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.1665 - val_loss: 10.0502
# Epoch 83/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.1637 - val_loss: 10.0602
# Epoch 84/500
# 5/5 [==============================] - 0s 31ms/step - loss: 2.1600 - val_loss: 10.0456
# Epoch 85/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.1589 - val_loss: 10.0351
# Epoch 86/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.1562 - val_loss: 10.0418
# Epoch 87/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1525 - val_loss: 10.0399
# Epoch 88/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.1507 - val_loss: 10.0567
# Epoch 89/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1474 - val_loss: 10.0616
# Epoch 90/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.1441 - val_loss: 10.0422
# Epoch 91/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1434 - val_loss: 10.0322
# Epoch 92/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.1406 - val_loss: 10.0326
# Epoch 93/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1375 - val_loss: 10.0278
# Epoch 94/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.1359 - val_loss: 10.0443
# Epoch 95/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.1326 - val_loss: 10.0492
# Epoch 96/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1300 - val_loss: 10.0339
# Epoch 97/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1293 - val_loss: 10.0261
# Epoch 98/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1266 - val_loss: 10.0221
# Epoch 99/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1241 - val_loss: 10.0180
# Epoch 100/500
# 5/5 [==============================] - 0s 30ms/step - loss: 2.1225 - val_loss: 10.0353
# Epoch 101/500
# 5/5 [==============================] - 0s 25ms/step - loss: 2.1186 - val_loss: 10.0219
# Epoch 102/500
# 5/5 [==============================] - 0s 25ms/step - loss: 2.1183 - val_loss: 10.0217
# Epoch 103/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.1159 - val_loss: 10.0342
# Epoch 104/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.1148 - val_loss: 10.0113
# Epoch 105/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1135 - val_loss: 10.0020
# Epoch 106/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.1115 - val_loss: 10.0364
# Epoch 107/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1050 - val_loss: 9.9710
# Epoch 108/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.1075 - val_loss: 10.0364
# Epoch 109/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0990 - val_loss: 9.9944
# Epoch 110/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0998 - val_loss: 9.9952
# Epoch 111/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.0973 - val_loss: 9.9983
# Epoch 112/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.0922 - val_loss: 9.9762
# Epoch 113/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0912 - val_loss: 9.9840
# Epoch 114/500
# 5/5 [==============================] - 0s 28ms/step - loss: 2.0882 - val_loss: 9.9875
# Epoch 115/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0844 - val_loss: 9.9759
# Epoch 116/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0831 - val_loss: 9.9668
# Epoch 117/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.0781 - val_loss: 9.9783
# Epoch 118/500
# 5/5 [==============================] - 0s 31ms/step - loss: 2.0743 - val_loss: 9.9631
# Epoch 119/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0731 - val_loss: 9.9787
# Epoch 120/500
# 5/5 [==============================] - 0s 25ms/step - loss: 2.0703 - val_loss: 9.9539
# Epoch 121/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0677 - val_loss: 9.9853
# Epoch 122/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0655 - val_loss: 9.9531
# Epoch 123/500
# 5/5 [==============================] - 0s 30ms/step - loss: 2.0659 - val_loss: 10.0042
# Epoch 124/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0652 - val_loss: 9.9424
# Epoch 125/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.0699 - val_loss: 10.0182
# Epoch 126/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.0750 - val_loss: 9.9165
# Epoch 127/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0908 - val_loss: 10.0612
# Epoch 128/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0999 - val_loss: 9.8982
# Epoch 129/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1395 - val_loss: 10.1455
# Epoch 130/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.1501 - val_loss: 9.8667
# Epoch 131/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.2203 - val_loss: 10.3000
# Epoch 132/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.1931 - val_loss: 9.8291
# Epoch 133/500
# 5/5 [==============================] - 0s 28ms/step - loss: 2.2563 - val_loss: 10.4928
# Epoch 134/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1191 - val_loss: 9.8465
# Epoch 135/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1286 - val_loss: 10.2976
# Epoch 136/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.0297 - val_loss: 9.8630
# Epoch 137/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0512 - val_loss: 10.0779
# Epoch 138/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0213 - val_loss: 9.9872
# Epoch 139/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.0334 - val_loss: 9.9795
# Epoch 140/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0354 - val_loss: 10.0493
# Epoch 141/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0258 - val_loss: 9.9581
# Epoch 142/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0366 - val_loss: 10.0802
# Epoch 143/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0238 - val_loss: 9.9474
# Epoch 144/500
# 5/5 [==============================] - 0s 59ms/step - loss: 2.0337 - val_loss: 10.0756
# Epoch 145/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0156 - val_loss: 9.9760
# Epoch 146/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0281 - val_loss: 10.0831
# Epoch 147/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0217 - val_loss: 9.9843
# Epoch 148/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0304 - val_loss: 10.0910
# Epoch 149/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0246 - val_loss: 9.9795
# Epoch 150/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0373 - val_loss: 10.1258
# Epoch 151/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0367 - val_loss: 9.9964
# Epoch 152/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0630 - val_loss: 10.1730
# Epoch 153/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0674 - val_loss: 9.9939
# Epoch 154/500
# 5/5 [==============================] - 0s 30ms/step - loss: 2.1129 - val_loss: 10.2627
# Epoch 155/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.1120 - val_loss: 10.0025
# Epoch 156/500
# 5/5 [==============================] - 0s 25ms/step - loss: 2.1839 - val_loss: 10.3790
# Epoch 157/500
# 5/5 [==============================] - 0s 25ms/step - loss: 2.1660 - val_loss: 10.0146
# Epoch 158/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.2437 - val_loss: 10.6393
# Epoch 159/500
# 5/5 [==============================] - 0s 25ms/step - loss: 2.1056 - val_loss: 10.0571
# Epoch 160/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1186 - val_loss: 10.4611
# Epoch 161/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0063 - val_loss: 10.0133
# Epoch 162/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0238 - val_loss: 10.2150
# Epoch 163/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.9749 - val_loss: 10.0736
# Epoch 164/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9919 - val_loss: 10.1223
# Epoch 165/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.9859 - val_loss: 10.1139
# Epoch 166/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9846 - val_loss: 10.0751
# Epoch 167/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9877 - val_loss: 10.1490
# Epoch 168/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.9774 - val_loss: 10.0926
# Epoch 169/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9842 - val_loss: 10.1649
# Epoch 170/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9753 - val_loss: 10.1206
# Epoch 171/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.9807 - val_loss: 10.1881
# Epoch 172/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9748 - val_loss: 10.1472
# Epoch 173/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9814 - val_loss: 10.2198
# Epoch 174/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.9761 - val_loss: 10.1722
# Epoch 175/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9860 - val_loss: 10.2491
# Epoch 176/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9853 - val_loss: 10.1940
# Epoch 177/500
# 5/5 [==============================] - 0s 25ms/step - loss: 2.0057 - val_loss: 10.2863
# Epoch 178/500
# 5/5 [==============================] - 0s 25ms/step - loss: 2.0153 - val_loss: 10.2132
# Epoch 179/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0635 - val_loss: 10.3443
# Epoch 180/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0989 - val_loss: 10.2246
# Epoch 181/500
# 5/5 [==============================] - 0s 25ms/step - loss: 2.2156 - val_loss: 10.4917
# Epoch 182/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.2578 - val_loss: 10.2810
# Epoch 183/500
# 5/5 [==============================] - 0s 25ms/step - loss: 2.4484 - val_loss: 11.1287
# Epoch 184/500
# 5/5 [==============================] - 0s 25ms/step - loss: 2.2222 - val_loss: 10.3714
# Epoch 185/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.2398 - val_loss: 10.9555
# Epoch 186/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0089 - val_loss: 10.2260
# Epoch 187/500
# 5/5 [==============================] - 0s 25ms/step - loss: 2.0184 - val_loss: 10.3986
# Epoch 188/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.9537 - val_loss: 10.1466
# Epoch 189/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9608 - val_loss: 10.2142
# Epoch 190/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9588 - val_loss: 10.2066
# Epoch 191/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9589 - val_loss: 10.1824
# Epoch 192/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9646 - val_loss: 10.2627
# Epoch 193/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9467 - val_loss: 10.2087
# Epoch 194/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9560 - val_loss: 10.2816
# Epoch 195/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9426 - val_loss: 10.2551
# Epoch 196/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9477 - val_loss: 10.3107
# Epoch 197/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.9395 - val_loss: 10.3050
# Epoch 198/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9440 - val_loss: 10.3560
# Epoch 199/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.9363 - val_loss: 10.3412
# Epoch 200/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.9407 - val_loss: 10.3750
# Epoch 201/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9347 - val_loss: 10.3640
# Epoch 202/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.9418 - val_loss: 10.3992
# Epoch 203/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9419 - val_loss: 10.3999
# Epoch 204/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9567 - val_loss: 10.4441
# Epoch 205/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9636 - val_loss: 10.4343
# Epoch 206/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0096 - val_loss: 10.4577
# Epoch 207/500
# 5/5 [==============================] - 0s 25ms/step - loss: 2.0926 - val_loss: 10.4670
# Epoch 208/500
# 5/5 [==============================] - 0s 29ms/step - loss: 2.2780 - val_loss: 10.6349
# Epoch 209/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.3913 - val_loss: 10.6013
# Epoch 210/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.7415 - val_loss: 11.8574
# Epoch 211/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.3008 - val_loss: 10.6767
# Epoch 212/500
# 5/5 [==============================] - 0s 56ms/step - loss: 2.2872 - val_loss: 11.2685
# Epoch 213/500
# 5/5 [==============================] - 0s 32ms/step - loss: 1.9660 - val_loss: 10.3058
# Epoch 214/500
# 5/5 [==============================] - 0s 32ms/step - loss: 1.9733 - val_loss: 10.4540
# Epoch 215/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.9208 - val_loss: 10.2681
# Epoch 216/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9388 - val_loss: 10.2886
# Epoch 217/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.9421 - val_loss: 10.3571
# Epoch 218/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9249 - val_loss: 10.3143
# Epoch 219/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9335 - val_loss: 10.3912
# Epoch 220/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.9139 - val_loss: 10.3798
# Epoch 221/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.9207 - val_loss: 10.4297
# Epoch 222/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.9109 - val_loss: 10.4515
# Epoch 223/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.9142 - val_loss: 10.4898
# Epoch 224/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.9057 - val_loss: 10.5023
# Epoch 225/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.9078 - val_loss: 10.5282
# Epoch 226/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9035 - val_loss: 10.5523
# Epoch 227/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9041 - val_loss: 10.5745
# Epoch 228/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.8999 - val_loss: 10.5917
# Epoch 229/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9004 - val_loss: 10.6083
# Epoch 230/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.8981 - val_loss: 10.6281
# Epoch 231/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8997 - val_loss: 10.6406
# Epoch 232/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.8991 - val_loss: 10.6649
# Epoch 233/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9057 - val_loss: 10.6764
# Epoch 234/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.9120 - val_loss: 10.7092
# Epoch 235/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9345 - val_loss: 10.7117
# Epoch 236/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.9699 - val_loss: 10.7590
# Epoch 237/500
# 5/5 [==============================] - 0s 25ms/step - loss: 2.0586 - val_loss: 10.7677
# Epoch 238/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1380 - val_loss: 10.7826
# Epoch 239/500
# 5/5 [==============================] - 0s 25ms/step - loss: 2.3974 - val_loss: 10.9887
# Epoch 240/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.4296 - val_loss: 10.8386
# Epoch 241/500
# 5/5 [==============================] - 0s 25ms/step - loss: 2.7803 - val_loss: 11.9293
# Epoch 242/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.2966 - val_loss: 10.8714
# Epoch 243/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.3085 - val_loss: 11.3561
# Epoch 244/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9698 - val_loss: 10.5674
# Epoch 245/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9646 - val_loss: 10.6355
# Epoch 246/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8676 - val_loss: 10.4093
# Epoch 247/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8856 - val_loss: 10.4207
# Epoch 248/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8694 - val_loss: 10.3783
# Epoch 249/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8549 - val_loss: 10.3018
# Epoch 250/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.8575 - val_loss: 10.2739
# Epoch 251/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8411 - val_loss: 10.2582
# Epoch 252/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8486 - val_loss: 10.2698
# Epoch 253/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8362 - val_loss: 10.2822
# Epoch 254/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8390 - val_loss: 10.3070
# Epoch 255/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8310 - val_loss: 10.3289
# Epoch 256/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.8314 - val_loss: 10.3590
# Epoch 257/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8269 - val_loss: 10.3794
# Epoch 258/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.8251 - val_loss: 10.3963
# Epoch 259/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8219 - val_loss: 10.4158
# Epoch 260/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8199 - val_loss: 10.4404
# Epoch 261/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8170 - val_loss: 10.4632
# Epoch 262/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.8147 - val_loss: 10.4873
# Epoch 263/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8121 - val_loss: 10.5113
# Epoch 264/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8094 - val_loss: 10.5357
# Epoch 265/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8072 - val_loss: 10.5573
# Epoch 266/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8048 - val_loss: 10.5826
# Epoch 267/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.8023 - val_loss: 10.6036
# Epoch 268/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7992 - val_loss: 10.6275
# Epoch 269/500
# 5/5 [==============================] - 0s 55ms/step - loss: 1.7978 - val_loss: 10.6462
# Epoch 270/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.7952 - val_loss: 10.6776
# Epoch 271/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.7938 - val_loss: 10.6898
# Epoch 272/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7914 - val_loss: 10.7239
# Epoch 273/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.7925 - val_loss: 10.7359
# Epoch 274/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7969 - val_loss: 10.7681
# Epoch 275/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8093 - val_loss: 10.7592
# Epoch 276/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8408 - val_loss: 10.8047
# Epoch 277/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.9165 - val_loss: 10.7594
# Epoch 278/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0500 - val_loss: 10.8291
# Epoch 279/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.4460 - val_loss: 10.8781
# Epoch 280/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.6475 - val_loss: 10.8537
# Epoch 281/500
# 5/5 [==============================] - 0s 27ms/step - loss: 3.5020 - val_loss: 13.3825
# Epoch 282/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.4383 - val_loss: 11.0958
# Epoch 283/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.3523 - val_loss: 11.7653
# Epoch 284/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8306 - val_loss: 10.3459
# Epoch 285/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8725 - val_loss: 10.3473
# Epoch 286/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8522 - val_loss: 10.2637
# Epoch 287/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.8541 - val_loss: 10.2631
# Epoch 288/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8708 - val_loss: 10.3849
# Epoch 289/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8096 - val_loss: 10.3792
# Epoch 290/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.8233 - val_loss: 10.4172
# Epoch 291/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7970 - val_loss: 10.4677
# Epoch 292/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8046 - val_loss: 10.5126
# Epoch 293/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.8030 - val_loss: 10.5500
# Epoch 294/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7973 - val_loss: 10.6018
# Epoch 295/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.8008 - val_loss: 10.6082
# Epoch 296/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.7921 - val_loss: 10.6429
# Epoch 297/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.7951 - val_loss: 10.6460
# Epoch 298/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.7893 - val_loss: 10.6712
# Epoch 299/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7900 - val_loss: 10.6817
# Epoch 300/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.7866 - val_loss: 10.7000
# Epoch 301/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7854 - val_loss: 10.7148
# Epoch 302/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.7835 - val_loss: 10.7302
# Epoch 303/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7814 - val_loss: 10.7506
# Epoch 304/500
# 5/5 [==============================] - 0s 39ms/step - loss: 1.7800 - val_loss: 10.7677
# Epoch 305/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.7776 - val_loss: 10.7889
# Epoch 306/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7764 - val_loss: 10.8062
# Epoch 307/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.7742 - val_loss: 10.8274
# Epoch 308/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.7727 - val_loss: 10.8433
# Epoch 309/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7706 - val_loss: 10.8624
# Epoch 310/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7692 - val_loss: 10.8768
# Epoch 311/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.7666 - val_loss: 10.8964
# Epoch 312/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.7659 - val_loss: 10.9074
# Epoch 313/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7631 - val_loss: 10.9259
# Epoch 314/500
# 5/5 [==============================] - 0s 31ms/step - loss: 1.7623 - val_loss: 10.9370
# Epoch 315/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7598 - val_loss: 10.9528
# Epoch 316/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.7583 - val_loss: 10.9657
# Epoch 317/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.7575 - val_loss: 10.9712
# Epoch 318/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.7542 - val_loss: 10.9911
# Epoch 319/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7534 - val_loss: 10.9967
# Epoch 320/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7512 - val_loss: 11.0134
# Epoch 321/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.7508 - val_loss: 11.0182
# Epoch 322/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.7476 - val_loss: 11.0455
# Epoch 323/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7471 - val_loss: 11.0457
# Epoch 324/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.7463 - val_loss: 11.0685
# Epoch 325/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.7466 - val_loss: 11.0664
# Epoch 326/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7483 - val_loss: 11.1051
# Epoch 327/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.7576 - val_loss: 11.0760
# Epoch 328/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7749 - val_loss: 11.1136
# Epoch 329/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.8212 - val_loss: 11.0585
# Epoch 330/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.9031 - val_loss: 11.1168
# Epoch 331/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.1586 - val_loss: 10.9888
# Epoch 332/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.4229 - val_loss: 11.1568
# Epoch 333/500
# 5/5 [==============================] - 0s 27ms/step - loss: 3.3250 - val_loss: 12.6533
# Epoch 334/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.6619 - val_loss: 10.8310
# Epoch 335/500
# 5/5 [==============================] - 0s 26ms/step - loss: 3.0527 - val_loss: 12.9701
# Epoch 336/500
# 5/5 [==============================] - 0s 55ms/step - loss: 2.0378 - val_loss: 10.5805
# Epoch 337/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.9563 - val_loss: 10.8173
# Epoch 338/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7252 - val_loss: 9.9119
# Epoch 339/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7911 - val_loss: 10.0594
# Epoch 340/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8155 - val_loss: 10.1494
# Epoch 341/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.7543 - val_loss: 9.9912
# Epoch 342/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7685 - val_loss: 10.1081
# Epoch 343/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.7161 - val_loss: 9.9670
# Epoch 344/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7208 - val_loss: 9.9642
# Epoch 345/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.7101 - val_loss: 9.9536
# Epoch 346/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7086 - val_loss: 9.9543
# Epoch 347/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7117 - val_loss: 9.9838
# Epoch 348/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7018 - val_loss: 9.9967
# Epoch 349/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.7049 - val_loss: 10.0238
# Epoch 350/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.6984 - val_loss: 10.0348
# Epoch 351/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6991 - val_loss: 10.0579
# Epoch 352/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6957 - val_loss: 10.0758
# Epoch 353/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6946 - val_loss: 10.0919
# Epoch 354/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6925 - val_loss: 10.1084
# Epoch 355/500
# 5/5 [==============================] - 0s 30ms/step - loss: 1.6903 - val_loss: 10.1234
# Epoch 356/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6896 - val_loss: 10.1410
# Epoch 357/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6867 - val_loss: 10.1616
# Epoch 358/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6861 - val_loss: 10.1821
# Epoch 359/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.6833 - val_loss: 10.1951
# Epoch 360/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6830 - val_loss: 10.2077
# Epoch 361/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.6802 - val_loss: 10.2231
# Epoch 362/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6793 - val_loss: 10.2360
# Epoch 363/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6766 - val_loss: 10.2519
# Epoch 364/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6762 - val_loss: 10.2639
# Epoch 365/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6733 - val_loss: 10.2779
# Epoch 366/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6731 - val_loss: 10.2851
# Epoch 367/500
# 5/5 [==============================] - 0s 31ms/step - loss: 1.6703 - val_loss: 10.2995
# Epoch 368/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.6699 - val_loss: 10.3100
# Epoch 369/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.6674 - val_loss: 10.3209
# Epoch 370/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6668 - val_loss: 10.3242
# Epoch 371/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6643 - val_loss: 10.3337
# Epoch 372/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6643 - val_loss: 10.3401
# Epoch 373/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6610 - val_loss: 10.3565
# Epoch 374/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.6620 - val_loss: 10.3521
# Epoch 375/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6590 - val_loss: 10.3629
# Epoch 376/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.6606 - val_loss: 10.3641
# Epoch 377/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.6573 - val_loss: 10.3818
# Epoch 378/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.6620 - val_loss: 10.3716
# Epoch 379/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6641 - val_loss: 10.3768
# Epoch 380/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6745 - val_loss: 10.3657
# Epoch 381/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6807 - val_loss: 10.3511
# Epoch 382/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7219 - val_loss: 10.3624
# Epoch 383/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7574 - val_loss: 10.3723
# Epoch 384/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.8806 - val_loss: 10.3708
# Epoch 385/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9476 - val_loss: 10.3561
# Epoch 386/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.2996 - val_loss: 10.6285
# Epoch 387/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.3017 - val_loss: 10.3694
# Epoch 388/500
# 5/5 [==============================] - 0s 25ms/step - loss: 2.8519 - val_loss: 12.2433
# Epoch 389/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.1221 - val_loss: 10.3330
# Epoch 390/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.2378 - val_loss: 10.8258
# Epoch 391/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8387 - val_loss: 10.0447
# Epoch 392/500
# 5/5 [==============================] - 0s 31ms/step - loss: 1.9220 - val_loss: 10.7791
# Epoch 393/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7033 - val_loss: 9.8408
# Epoch 394/500
# 5/5 [==============================] - 0s 54ms/step - loss: 1.6845 - val_loss: 9.9662
# Epoch 395/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6663 - val_loss: 9.9370
# Epoch 396/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6666 - val_loss: 9.9030
# Epoch 397/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.6805 - val_loss: 9.9705
# Epoch 398/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.6542 - val_loss: 9.9614
# Epoch 399/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.6593 - val_loss: 9.9995
# Epoch 400/500
# 5/5 [==============================] - 0s 31ms/step - loss: 1.6403 - val_loss: 9.9963
# Epoch 401/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.6453 - val_loss: 9.9950
# Epoch 402/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6362 - val_loss: 10.0035
# Epoch 403/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6375 - val_loss: 10.0269
# Epoch 404/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6336 - val_loss: 10.0473
# Epoch 405/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.6326 - val_loss: 10.0607
# Epoch 406/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.6316 - val_loss: 10.0708
# Epoch 407/500
# 5/5 [==============================] - 0s 30ms/step - loss: 1.6290 - val_loss: 10.0868
# Epoch 408/500
# 5/5 [==============================] - 0s 31ms/step - loss: 1.6286 - val_loss: 10.1028
# Epoch 409/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.6255 - val_loss: 10.1158
# Epoch 410/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.6253 - val_loss: 10.1229
# Epoch 411/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6227 - val_loss: 10.1350
# Epoch 412/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6215 - val_loss: 10.1435
# Epoch 413/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6198 - val_loss: 10.1550
# Epoch 414/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.6181 - val_loss: 10.1641
# Epoch 415/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.6170 - val_loss: 10.1682
# Epoch 416/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6152 - val_loss: 10.1780
# Epoch 417/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.6141 - val_loss: 10.1829
# Epoch 418/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6121 - val_loss: 10.1926
# Epoch 419/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.6112 - val_loss: 10.1935
# Epoch 420/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.6089 - val_loss: 10.1985
# Epoch 421/500
# 5/5 [==============================] - 0s 62ms/step - loss: 1.6105 - val_loss: 10.1869
# Epoch 422/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.6057 - val_loss: 10.1743
# Epoch 423/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6078 - val_loss: 10.1763
# Epoch 424/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6059 - val_loss: 10.1986
# Epoch 425/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.6083 - val_loss: 10.1854
# Epoch 426/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.6096 - val_loss: 10.1860
# Epoch 427/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6230 - val_loss: 10.1932
# Epoch 428/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6308 - val_loss: 10.1819
# Epoch 429/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6774 - val_loss: 10.1650
# Epoch 430/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7239 - val_loss: 10.1904
# Epoch 431/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.8899 - val_loss: 10.2210
# Epoch 432/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9915 - val_loss: 10.1384
# Epoch 433/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.4721 - val_loss: 10.7853
# Epoch 434/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.3295 - val_loss: 10.1036
# Epoch 435/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.8583 - val_loss: 12.3977
# Epoch 436/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0273 - val_loss: 10.1745
# Epoch 437/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.9903 - val_loss: 10.8270
# Epoch 438/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.6332 - val_loss: 9.7590
# Epoch 439/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6565 - val_loss: 9.9271
# Epoch 440/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6027 - val_loss: 9.7828
# Epoch 441/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6227 - val_loss: 9.8186
# Epoch 442/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.6332 - val_loss: 9.8927
# Epoch 443/500
# 5/5 [==============================] - 0s 25ms/step - loss: 1.6101 - val_loss: 9.8952
# Epoch 444/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.6199 - val_loss: 9.9390
# Epoch 445/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.5962 - val_loss: 9.9483
# Epoch 446/500
# 5/5 [==============================] - 0s 52ms/step - loss: 1.6028 - val_loss: 9.9445
# Epoch 447/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.5924 - val_loss: 9.9398
# Epoch 448/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.5955 - val_loss: 9.9441
# Epoch 449/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.5918 - val_loss: 9.9545
# Epoch 450/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.5908 - val_loss: 9.9643
# Epoch 451/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.5906 - val_loss: 9.9628
# Epoch 452/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.5879 - val_loss: 9.9582
# Epoch 453/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.5884 - val_loss: 9.9592
# Epoch 454/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.5852 - val_loss: 9.9645
# Epoch 455/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.5861 - val_loss: 9.9744
# Epoch 456/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.5825 - val_loss: 9.9881
# Epoch 457/500
# 5/5 [==============================] - 0s 30ms/step - loss: 1.5828 - val_loss: 9.9835
# Epoch 458/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.5813 - val_loss: 9.9670
# Epoch 459/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.5804 - val_loss: 9.9733
# Epoch 460/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.5783 - val_loss: 9.9848
# Epoch 461/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.5783 - val_loss: 9.9694
# Epoch 462/500
# 5/5 [==============================] - 0s 30ms/step - loss: 1.5760 - val_loss: 9.9708
# Epoch 463/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.5752 - val_loss: 9.9743
# Epoch 464/500
# 5/5 [==============================] - 0s 43ms/step - loss: 1.5737 - val_loss: 9.9639
# Epoch 465/500
# 5/5 [==============================] - 0s 29ms/step - loss: 1.5735 - val_loss: 9.9703
# Epoch 466/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.5710 - val_loss: 9.9737
# Epoch 467/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.5726 - val_loss: 9.9619
# Epoch 468/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.5692 - val_loss: 9.9712
# Epoch 469/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.5708 - val_loss: 9.9714
# Epoch 470/500
# 5/5 [==============================] - 0s 31ms/step - loss: 1.5686 - val_loss: 9.9581
# Epoch 471/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.5718 - val_loss: 9.9556
# Epoch 472/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.5693 - val_loss: 9.9705
# Epoch 473/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.5793 - val_loss: 9.9615
# Epoch 474/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.5767 - val_loss: 9.9717
# Epoch 475/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.5958 - val_loss: 9.9570
# Epoch 476/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.6040 - val_loss: 9.9476
# Epoch 477/500
# 5/5 [==============================] - 0s 31ms/step - loss: 1.6555 - val_loss: 9.9670
# Epoch 478/500
# 5/5 [==============================] - 0s 31ms/step - loss: 1.6769 - val_loss: 9.9770
# Epoch 479/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.8139 - val_loss: 10.0354
# Epoch 480/500
# 5/5 [==============================] - 0s 29ms/step - loss: 1.8572 - val_loss: 9.9182
# Epoch 481/500
# 5/5 [==============================] - 0s 35ms/step - loss: 2.1601 - val_loss: 10.4018
# Epoch 482/500
# 5/5 [==============================] - 0s 31ms/step - loss: 2.0677 - val_loss: 9.9018
# Epoch 483/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.4868 - val_loss: 11.1260
# Epoch 484/500
# 5/5 [==============================] - 0s 26ms/step - loss: 2.0693 - val_loss: 9.8569
# Epoch 485/500
# 5/5 [==============================] - 0s 27ms/step - loss: 2.2311 - val_loss: 11.2621
# Epoch 486/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.7225 - val_loss: 9.8362
# Epoch 487/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.7185 - val_loss: 10.0396
# Epoch 488/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.5579 - val_loss: 9.5932
# Epoch 489/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.5866 - val_loss: 9.7087
# Epoch 490/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.5570 - val_loss: 9.6781
# Epoch 491/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.5634 - val_loss: 9.7312
# Epoch 492/500
# 5/5 [==============================] - 0s 26ms/step - loss: 1.5700 - val_loss: 9.7727
# Epoch 493/500
# 5/5 [==============================] - 0s 54ms/step - loss: 1.5584 - val_loss: 9.7750
# Epoch 494/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.5642 - val_loss: 9.7782
# Epoch 495/500
# 5/5 [==============================] - 0s 33ms/step - loss: 1.5502 - val_loss: 9.7653
# Epoch 496/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.5553 - val_loss: 9.7696
# Epoch 497/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.5469 - val_loss: 9.7667
# Epoch 498/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.5501 - val_loss: 9.7720
# Epoch 499/500
# 5/5 [==============================] - 0s 28ms/step - loss: 1.5447 - val_loss: 9.7686
# Epoch 500/500
# 5/5 [==============================] - 0s 27ms/step - loss: 1.5463 - val_loss: 9.7720

# %% [markdown]
# ### <a name="EvaluationLSTM">c - Evaluation

# %%
y_predlstm = lstm_model.predict(x_test)
# Out:
# 1/1 [==============================] - 0s 310ms/step

# %%
print("Données de Test\t\tDonnées prédites")
for i in range(len(y_test )):
    print(f"{y_test[i]}\t\t{y_predlstm[i]}")
# Out:
# Données de Test		Données prédites
# [21.430241]		[17.433699]
# [23.575517]		[18.675882]
# [23.334206]		[16.033592]
# [28.038383]		[20.985495]
# [16.763869]		[23.254347]
# [19.792754]		[17.750511]
# [16.427305]		[20.108871]
# [21.000742]		[16.138855]
# [20.681002]		[19.006325]
# [21.83489]		[15.859046]
# [23.93020353]		[21.272518]
# [22.93035694]		[21.049269]
# [23.26333992]		[21.324644]
# [25.25003022]		[23.347624]
# [25.80609]		[23.054506]
# [29.665356]		[22.437845]
# [21.654285]		[24.735003]
# [18.264945]		[22.258694]
# [23.107677]		[21.48849]
# [22.91251]		[20.57468]
# [19.43174]		[17.076546]

# %%
#len(test_time[:len(y_test)])
len(y_test)
# Out:
# 21

# %%
plt.plot(np.arange(0, len(y_train)), y_train, 'g', label="History")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test, marker='.', label="Données Actuelles")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_predlstm, 'r', label="Prédiction")
plt.ylabel('Détail de Vente')
plt.xlabel('Période')
plt.legend()
plt.show();

# %%
# Visualisation de la prédiction
forecast_plot(forecast_data = y_test, forecast_label = 'LSTM Forecast',test_time=test_time[3:],test_data=y_predlstm)

# %%
# Accuracy
lstm_forecast = forcast_accuracy(y_predlstm,y_test)
#print('Test Score: %.2f RMSE' % (lstm_forecast))

Precision['LSTM ACC'] =  lstm_forecast
Precision
# Out:
#       NAÏVE ACC  SEMA ACC  ADD_ADD_ACC  ADD_MUL_ACC  MUL_ADD_ACC  MUL_MUL_ACC  \
# RMSE   3.969457  6.142934     3.105467     2.971185     2.648327       2.3696
#
#       SARIMA ACC   MLP ACC  LSTM ACC
# RMSE     5.24135  4.148541  4.264403

# %% [markdown]
# # <a name="Conclusion">5. Conclusion
#
# De ce qui precède, il faut faut retenir que le meilleur modèle est la `méthode de Holt-Winters` à tendance multiplicative et à saisonnalité multiplicative, car il a la meilleure mésure de prédiction en terme d'Erreur quadratique moyenne (`RMSE`).
#
# Mais n'oublions pas que cela est valable seulement sur l'echantillons du dataset utilisé. Car sur une plus longue durée ou un autre dataset il est fort probable que ça soit un autre, tout dépend uniquement des données que nous avons.

# %%
Precision
# Out:
#       NAÏVE ACC  SEMA ACC  ADD_ADD_ACC  ADD_MUL_ACC  MUL_ADD_ACC  MUL_MUL_ACC  \
# RMSE   3.969457  6.142934     3.105467     2.971185     2.648327       2.3696
#
#       SARIMA ACC   MLP ACC  LSTM ACC
# RMSE     5.24135  4.148541  4.264403
